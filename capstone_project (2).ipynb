# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt
# from influxdb import InfluxDBClient
import statsmodels.tsa.api as smt
# %matplotlib inline
import os
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
pd.set_option("display.max_rows",2000)
pd.set_option("display.max_columns",None)
plt.style.use('Solarize_Light2')

# %% [markdown]
# ## Importing the Dataset

# %%
# --- country data (country, region, Income Group)
country = pd.read_csv(r'C:\python\capstone_project\CSV_files\Metadata_Country.csv')

# --- Population data ( Population countrywise)
population = pd.read_csv(r'C:\python\capstone_project\CSV_files\country_population.csv')

# --- Fertilty data( Fertility_rate countrywise)
fertility_rate = pd.read_csv(r'C:\python\capstone_project\CSV_files\fertility_rate.csv')

# ---  Life_expectancy data(avg Life_expectancy country wise)
life_expectancy = pd.read_csv(r'C:\python\capstone_project\CSV_files\life_expectancy.csv')

# --- Migration data(number of immigranted people - number of emmigranted people)
net_migration = pd.read_csv(r'C:\python\capstone_project\CSV_files\Net_migration.csv',engine='python')

# -- Indicator data (Birth_rate, death_rate,age_group_population,gender_population)
world_indicator = pd.read_excel(r'C:\python\capstone_project\CSV_files\world_indicator.xlsx')

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Filtering the unwanted variables from each dataset

# %%
# -- Country data
country=country[['Country Code','Region','IncomeGroup']]


unwanted_columns=['Indicator Name','Indicator Code','Country Name'] # Unwanted columns for the analysis

# -- Population data
population.drop(unwanted_columns[:2],axis=1,inplace=True)

# --Fertility data
fertility_rate.drop(unwanted_columns,axis=1,inplace=True)

# # --Life_expectancy data
life_expectancy.drop(unwanted_columns,axis=1,inplace=True)

# # --Net_migration data
net_migration.drop(unwanted_columns+['2017','2018','2019'],axis=1,inplace=True) # Analysing the records till year 2016

# # --World_Indicator data
world_indicator.drop(['2017','2018'],axis=1,inplace=True) # Analysing the records till year 2016

# %% [markdown]
# ## Melting the columns to rows

# %%
# --- Years range for melting the columns to rows
years=[str(i) for i in range(1960,2017)]

# --- Constant columns for melting
variables=['Country Name','Country Code']

# %%
population=pd.melt(population,id_vars=variables,
                      value_vars=years,
                      var_name='Year',
                      value_name='Population')

fertility_rate=pd.melt(fertility_rate,id_vars=variables[1],
                      value_vars=years,
                      var_name='Year',
                      value_name='Fertility_rate')

life_expectancy=pd.melt(life_expectancy,id_vars=variables[1],
                      value_vars=years,
                      var_name='Year',
                      value_name='Life_expectancy')

net_migration=pd.melt(net_migration,id_vars=variables[1],
                      value_vars=years,
                      var_name='Year',
                      value_name='Net_migration')

world_indicator=pd.melt(world_indicator,id_vars=variables+['Series Name'],
                      value_vars=years,
                      var_name='Year',
                      value_name='Values')

# %% [markdown]
# ### Converting rows to columns using pivot table

# %%
world_indicator=world_indicator[['Country Code','Year','Series Name','Values']].pivot_table(values='Values',
                                                index=['Country Code','Year'],columns='Series Name',aggfunc=np.sum)

# %%
world_indicator.reset_index(level=['Country Code','Year'],inplace=True)

# %% [markdown]
# ## Merging the dataset

# %%
df = pd.merge(country, population, how='left', on='Country Code')
df = pd.merge(df, life_expectancy, how='left', on=['Country Code', 'Year'])
df = pd.merge(df, fertility_rate, how='left', on=['Country Code', 'Year'])
df = pd.merge(df, net_migration, how='left', on=['Country Code', 'Year'])
df = pd.merge(df, world_indicator, how='left', on=['Country Code', 'Year'])

# %%
df.sort_values(by=['Country Name','Year'],inplace=True)
df.reset_index(drop=True,inplace=True)

# %%
df.head()
# Out:
#   Country Code      Region IncomeGroup Country Name  Year  Population  \
# 0          AFG  South Asia  Low income  Afghanistan  1960   8996351.0
# 1          AFG  South Asia  Low income  Afghanistan  1961   9166764.0
# 2          AFG  South Asia  Low income  Afghanistan  1962   9345868.0
# 3          AFG  South Asia  Low income  Afghanistan  1963   9533954.0
# 4          AFG  South Asia  Low income  Afghanistan  1964   9731361.0
#
#    Life_expectancy  Fertility_rate  Net_migration  \
# 0           32.292            7.45            NaN
# 1           32.742            7.45            NaN
# 2           33.185            7.45       -20000.0
# 3           33.624            7.45            NaN
# 4           34.060            7.45            NaN
#
#   Age population, age 0, male, interpolated  \
# 0                                    178269
# 1                                    182276
# 2                                    186730
# 3                                    191614
# 4                                    196930
#
#   Birth rate, crude (per 1,000 people) Death rate, crude (per 1,000 people)  \
# 0                               51.279                               32.219
# 1                               51.373                               31.649
# 2                               51.457                               31.093
# 3                                51.53                               30.551
# 4                               51.589                               30.022
#
#   GDP growth (annual %) Population ages 0-14 (% of total)  \
# 0                    ..                                ..
# 1                    ..                                ..
# 2                    ..                                ..
# 3                    ..                                ..
# 4                    ..                                ..
#
#   Population ages 0-14, female Population ages 15-64 (% of total)  \
# 0                           ..                                 ..
# 1                           ..                                 ..
# 2                           ..                                 ..
# 3                           ..                                 ..
# 4                           ..                                 ..
#
#   Population ages 15-64, female Population ages 15-64, male  \
# 0                            ..                          ..
# 1                            ..                          ..
# 2                            ..                          ..
# 3                            ..                          ..
# 4                            ..                          ..
#
#   Population ages 15-64, total Population ages 65 and above (% of total)  \
# 0                           ..                                   2.79831
# 1                           ..                                   2.80813
# 2                           ..                                   2.80411
# 3                           ..                                   2.78617
# 4                           ..                                   2.75422
#
#   Population ages 65 and above, female Population, female  \
# 0                               115755                 ..
# 1                               118864                 ..
# 2                               121786                 ..
# 3                               124431                 ..
# 4                               126641                 ..
#
#   Population, female (% of total) Population, total
# 0                              ..                ..
# 1                              ..                ..
# 2                              ..                ..
# 3                              ..                ..
# 4                              ..                ..

# %%
# Removing Unwanted Columns Level1:

df.drop(['Country Code','Age population, age 0, male, interpolated'],axis=1,inplace=True)
df.head()
# Out:
#        Region IncomeGroup Country Name  Year  Population  Life_expectancy  \
# 0  South Asia  Low income  Afghanistan  1960   8996351.0           32.292
# 1  South Asia  Low income  Afghanistan  1961   9166764.0           32.742
# 2  South Asia  Low income  Afghanistan  1962   9345868.0           33.185
# 3  South Asia  Low income  Afghanistan  1963   9533954.0           33.624
# 4  South Asia  Low income  Afghanistan  1964   9731361.0           34.060
#
#    Fertility_rate  Net_migration Birth rate, crude (per 1,000 people)  \
# 0            7.45            NaN                               51.279
# 1            7.45            NaN                               51.373
# 2            7.45       -20000.0                               51.457
# 3            7.45            NaN                                51.53
# 4            7.45            NaN                               51.589
#
#   Death rate, crude (per 1,000 people) GDP growth (annual %)  \
# 0                               32.219                    ..
# 1                               31.649                    ..
# 2                               31.093                    ..
# 3                               30.551                    ..
# 4                               30.022                    ..
#
#   Population ages 0-14 (% of total) Population ages 0-14, female  \
# 0                                ..                           ..
# 1                                ..                           ..
# 2                                ..                           ..
# 3                                ..                           ..
# 4                                ..                           ..
#
#   Population ages 15-64 (% of total) Population ages 15-64, female  \
# 0                                 ..                            ..
# 1                                 ..                            ..
# 2                                 ..                            ..
# 3                                 ..                            ..
# 4                                 ..                            ..
#
#   Population ages 15-64, male Population ages 15-64, total  \
# 0                          ..                           ..
# 1                          ..                           ..
# 2                          ..                           ..
# 3                          ..                           ..
# 4                          ..                           ..
#
#   Population ages 65 and above (% of total)  \
# 0                                   2.79831
# 1                                   2.80813
# 2                                   2.80411
# 3                                   2.78617
# 4                                   2.75422
#
#   Population ages 65 and above, female Population, female  \
# 0                               115755                 ..
# 1                               118864                 ..
# 2                               121786                 ..
# 3                               124431                 ..
# 4                               126641                 ..
#
#   Population, female (% of total) Population, total
# 0                              ..                ..
# 1                              ..                ..
# 2                              ..                ..
# 3                              ..                ..
# 4                              ..                ..

# %% [markdown]
# ### Adjusting the population accuracy

# %%
val=pd.DataFrame(map(lambda i,j: i if (j=='..' or j!=j) else j if j!=i else i,df['Population'],df['Population, total']))

df.insert(loc=6, column='Total_Population', value=val)

df.drop(['Population','Population, total'],axis=1,inplace=True)

# %%
df.head()
# Out:
#        Region IncomeGroup Country Name  Year  Life_expectancy  \
# 0  South Asia  Low income  Afghanistan  1960           32.292
# 1  South Asia  Low income  Afghanistan  1961           32.742
# 2  South Asia  Low income  Afghanistan  1962           33.185
# 3  South Asia  Low income  Afghanistan  1963           33.624
# 4  South Asia  Low income  Afghanistan  1964           34.060
#
#    Total_Population  Fertility_rate  Net_migration  \
# 0         8996351.0            7.45            NaN
# 1         9166764.0            7.45            NaN
# 2         9345868.0            7.45       -20000.0
# 3         9533954.0            7.45            NaN
# 4         9731361.0            7.45            NaN
#
#   Birth rate, crude (per 1,000 people) Death rate, crude (per 1,000 people)  \
# 0                               51.279                               32.219
# 1                               51.373                               31.649
# 2                               51.457                               31.093
# 3                                51.53                               30.551
# 4                               51.589                               30.022
#
#   GDP growth (annual %) Population ages 0-14 (% of total)  \
# 0                    ..                                ..
# 1                    ..                                ..
# 2                    ..                                ..
# 3                    ..                                ..
# 4                    ..                                ..
#
#   Population ages 0-14, female Population ages 15-64 (% of total)  \
# 0                           ..                                 ..
# 1                           ..                                 ..
# 2                           ..                                 ..
# 3                           ..                                 ..
# 4                           ..                                 ..
#
#   Population ages 15-64, female Population ages 15-64, male  \
# 0                            ..                          ..
# 1                            ..                          ..
# 2                            ..                          ..
# 3                            ..                          ..
# 4                            ..                          ..
#
#   Population ages 15-64, total Population ages 65 and above (% of total)  \
# 0                           ..                                   2.79831
# 1                           ..                                   2.80813
# 2                           ..                                   2.80411
# 3                           ..                                   2.78617
# 4                           ..                                   2.75422
#
#   Population ages 65 and above, female Population, female  \
# 0                               115755                 ..
# 1                               118864                 ..
# 2                               121786                 ..
# 3                               124431                 ..
# 4                               126641                 ..
#
#   Population, female (% of total)
# 0                              ..
# 1                              ..
# 2                              ..
# 3                              ..
# 4                              ..

# %% [markdown]
# ### Checking for characters or words other than alphanumerics

# %%
(df.isnull().sum())+((df=='..').sum())
# Out:
# Region                                        2622
# IncomeGroup                                   2622
# Country Name                                     0
# Year                                             0
# Life_expectancy                               1244
# Total_Population                               106
# Fertility_rate                                1221
# Net_migration                                12363
# Birth rate, crude (per 1,000 people)          3600
# Death rate, crude (per 1,000 people)          3624
# GDP growth (annual %)                         6087
# Population ages 0-14 (% of total)             5924
# Population ages 0-14, female                  5955
# Population ages 15-64 (% of total)            5920
# Population ages 15-64, female                 5955
# Population ages 15-64, male                   5955
# Population ages 15-64, total                  5955
# Population ages 65 and above (% of total)     3998
# Population ages 65 and above, female          4001
# Population, female                            5955
# Population, female (% of total)               5924
# dtype: int64

# %%
# Converting the characters which has '..' 
df[df=='..']=np.nan

# %%
df.head()
# Out:
#        Region IncomeGroup Country Name  Year  Life_expectancy  \
# 0  South Asia  Low income  Afghanistan  1960           32.292
# 1  South Asia  Low income  Afghanistan  1961           32.742
# 2  South Asia  Low income  Afghanistan  1962           33.185
# 3  South Asia  Low income  Afghanistan  1963           33.624
# 4  South Asia  Low income  Afghanistan  1964           34.060
#
#    Total_Population  Fertility_rate  Net_migration  \
# 0         8996351.0            7.45            NaN
# 1         9166764.0            7.45            NaN
# 2         9345868.0            7.45       -20000.0
# 3         9533954.0            7.45            NaN
# 4         9731361.0            7.45            NaN
#
#   Birth rate, crude (per 1,000 people) Death rate, crude (per 1,000 people)  \
# 0                               51.279                               32.219
# 1                               51.373                               31.649
# 2                               51.457                               31.093
# 3                                51.53                               30.551
# 4                               51.589                               30.022
#
#   GDP growth (annual %) Population ages 0-14 (% of total)  \
# 0                   NaN                               NaN
# 1                   NaN                               NaN
# 2                   NaN                               NaN
# 3                   NaN                               NaN
# 4                   NaN                               NaN
#
#   Population ages 0-14, female Population ages 15-64 (% of total)  \
# 0                          NaN                                NaN
# 1                          NaN                                NaN
# 2                          NaN                                NaN
# 3                          NaN                                NaN
# 4                          NaN                                NaN
#
#   Population ages 15-64, female Population ages 15-64, male  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#   Population ages 15-64, total Population ages 65 and above (% of total)  \
# 0                          NaN                                   2.79831
# 1                          NaN                                   2.80813
# 2                          NaN                                   2.80411
# 3                          NaN                                   2.78617
# 4                          NaN                                   2.75422
#
#   Population ages 65 and above, female Population, female  \
# 0                               115755                NaN
# 1                               118864                NaN
# 2                               121786                NaN
# 3                               124431                NaN
# 4                               126641                NaN
#
#   Population, female (% of total)
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %%
# Removing unwanted rows:
df=df[df['Region'].notna()]
df.head()
# Out:
#        Region IncomeGroup Country Name  Year  Life_expectancy  \
# 0  South Asia  Low income  Afghanistan  1960           32.292
# 1  South Asia  Low income  Afghanistan  1961           32.742
# 2  South Asia  Low income  Afghanistan  1962           33.185
# 3  South Asia  Low income  Afghanistan  1963           33.624
# 4  South Asia  Low income  Afghanistan  1964           34.060
#
#    Total_Population  Fertility_rate  Net_migration  \
# 0         8996351.0            7.45            NaN
# 1         9166764.0            7.45            NaN
# 2         9345868.0            7.45       -20000.0
# 3         9533954.0            7.45            NaN
# 4         9731361.0            7.45            NaN
#
#   Birth rate, crude (per 1,000 people) Death rate, crude (per 1,000 people)  \
# 0                               51.279                               32.219
# 1                               51.373                               31.649
# 2                               51.457                               31.093
# 3                                51.53                               30.551
# 4                               51.589                               30.022
#
#   GDP growth (annual %) Population ages 0-14 (% of total)  \
# 0                   NaN                               NaN
# 1                   NaN                               NaN
# 2                   NaN                               NaN
# 3                   NaN                               NaN
# 4                   NaN                               NaN
#
#   Population ages 0-14, female Population ages 15-64 (% of total)  \
# 0                          NaN                                NaN
# 1                          NaN                                NaN
# 2                          NaN                                NaN
# 3                          NaN                                NaN
# 4                          NaN                                NaN
#
#   Population ages 15-64, female Population ages 15-64, male  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#   Population ages 15-64, total Population ages 65 and above (% of total)  \
# 0                          NaN                                   2.79831
# 1                          NaN                                   2.80813
# 2                          NaN                                   2.80411
# 3                          NaN                                   2.78617
# 4                          NaN                                   2.75422
#
#   Population ages 65 and above, female Population, female  \
# 0                               115755                NaN
# 1                               118864                NaN
# 2                               121786                NaN
# 3                               124431                NaN
# 4                               126641                NaN
#
#   Population, female (% of total)
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# ### Missing Values & Imputation

# %%
pd.DataFrame(round(df.isnull().sum()/df.shape[0]*100,2),columns=['Missing_values in (%)'])
# Out:
#                                            Missing_values in (%)
# Region                                                      0.00
# IncomeGroup                                                 0.00
# Country Name                                                0.00
# Year                                                        0.00
# Life_expectancy                                            10.06
# Total_Population                                            0.86
# Fertility_rate                                              9.87
# Net_migration                                              82.84
# Birth rate, crude (per 1,000 people)                        7.91
# Death rate, crude (per 1,000 people)                        8.10
# GDP growth (annual %)                                      28.01
# Population ages 0-14 (% of total)                          26.70
# Population ages 0-14, female                               26.95
# Population ages 15-64 (% of total)                         26.66
# Population ages 15-64, female                              26.95
# Population ages 15-64, male                                26.95
# Population ages 15-64, total                               26.95
# Population ages 65 and above (% of total)                  11.12
# Population ages 65 and above, female                       11.15
# Population, female                                         26.95
# Population, female (% of total)                            26.70

# %% [markdown]
# <b>Removing the columns which has more than 50% of missing values</b>

# %%
bandwidth_50_col=pd.DataFrame(round(df.isnull().sum()/df.shape[0]*100),columns=['Missing_values in (%)'])
col=bandwidth_50_col[bandwidth_50_col['Missing_values in (%)']>50].index
df.drop(col,axis=1,inplace=True)
df.head()
# Out:
#        Region IncomeGroup Country Name  Year  Life_expectancy  \
# 0  South Asia  Low income  Afghanistan  1960           32.292
# 1  South Asia  Low income  Afghanistan  1961           32.742
# 2  South Asia  Low income  Afghanistan  1962           33.185
# 3  South Asia  Low income  Afghanistan  1963           33.624
# 4  South Asia  Low income  Afghanistan  1964           34.060
#
#    Total_Population  Fertility_rate Birth rate, crude (per 1,000 people)  \
# 0         8996351.0            7.45                               51.279
# 1         9166764.0            7.45                               51.373
# 2         9345868.0            7.45                               51.457
# 3         9533954.0            7.45                                51.53
# 4         9731361.0            7.45                               51.589
#
#   Death rate, crude (per 1,000 people) GDP growth (annual %)  \
# 0                               32.219                   NaN
# 1                               31.649                   NaN
# 2                               31.093                   NaN
# 3                               30.551                   NaN
# 4                               30.022                   NaN
#
#   Population ages 0-14 (% of total) Population ages 0-14, female  \
# 0                               NaN                          NaN
# 1                               NaN                          NaN
# 2                               NaN                          NaN
# 3                               NaN                          NaN
# 4                               NaN                          NaN
#
#   Population ages 15-64 (% of total) Population ages 15-64, female  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#   Population ages 15-64, male Population ages 15-64, total  \
# 0                         NaN                          NaN
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                         NaN                          NaN
# 4                         NaN                          NaN
#
#   Population ages 65 and above (% of total)  \
# 0                                   2.79831
# 1                                   2.80813
# 2                                   2.80411
# 3                                   2.78617
# 4                                   2.75422
#
#   Population ages 65 and above, female Population, female  \
# 0                               115755                NaN
# 1                               118864                NaN
# 2                               121786                NaN
# 3                               124431                NaN
# 4                               126641                NaN
#
#   Population, female (% of total)
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# # Imputation Process:</br>
#
# ### Target Variable - Total_Population
# <p>
# For Imputing Total_popualtion we cannot use Traditional use mean/Median Imputation.<br>
# We need to use other methods to impute since the records are distinct metric. <br>
#
# <b>Method_1 Population_Projection:</b><br>
#                  Population projections are simply mathematical formulas that use current populations and<br>
# rates of growth to estimate future populations.<br>
#
#                Nt = P e^(r * t)
#
#                Nt  = Number of People at Future time
#                 P  = Present Population
#                 e  = base of the natural logarithms (2.71828)
#                 r  = natrual Increase ( (Birth_rate - Death_rate)/100)
#                 t  = represents the time period involved
#
# By using population Projection formula we can impute the Popualtion.<br>
# However, Projections for specific countries and age groups have not been as accurate.<br>In general, projections of future population size tend to be more uncertain, or less accurate:
# <ul><ul>
# <li>For less developed countries than for more developed countries.
# </li>
# <li>
# For smaller countries than larger ones.
# </li>
# <li>
# For younger and older age groups than for middle age groups, because incorrect assumptions<br> about fertility and mortality have a greater effect at older and younger ages
#     </li>
#     <li>
# For longer periods (more than two decades) than shorter periods, because of the compounding effects of incorrect assumptions over time.
#     </li>
#     </ul></ul>
#
# <b>Method_2: Using Population_growth_rate:</b><br>
# We can populate new field (Population_growth_rate) using population feature and impute those ,since we have seen that<br>
# the Population for each country is increasing every year.
# This is used for Instead of Reverse projection to find the population for the past year from present year.
#
# For populaiton projection or to find the population for future year. we cannot use growth rate, instead we can use
# other varibales to Impute like<br>
#
#                   population=present_population + no. of births - no.of deaths + Net_migration
#
#                       * Net_Migration  = No. of immigrants - No.of emmigrants
#
# </p>

# %%
# -- creating new columns (population growth rate)

val=np.where(df['Year']=="1960",0,
    np.where((df['Total_Population'].notna()) & (df['Total_Population'].shift().notna()),
    ((df['Total_Population']-df['Total_Population'].shift())/df['Total_Population'].shift()*100).round(1),np.nan))

df.insert(loc=6, column='Population_growth_rate(%)', value=val)

# %%
df.head()
# Out:
#        Region IncomeGroup Country Name  Year  Life_expectancy  \
# 0  South Asia  Low income  Afghanistan  1960           32.292
# 1  South Asia  Low income  Afghanistan  1961           32.742
# 2  South Asia  Low income  Afghanistan  1962           33.185
# 3  South Asia  Low income  Afghanistan  1963           33.624
# 4  South Asia  Low income  Afghanistan  1964           34.060
#
#    Total_Population  Population_growth_rate(%)  Fertility_rate  \
# 0         8996351.0                        0.0            7.45
# 1         9166764.0                        1.9            7.45
# 2         9345868.0                        2.0            7.45
# 3         9533954.0                        2.0            7.45
# 4         9731361.0                        2.1            7.45
#
#   Birth rate, crude (per 1,000 people) Death rate, crude (per 1,000 people)  \
# 0                               51.279                               32.219
# 1                               51.373                               31.649
# 2                               51.457                               31.093
# 3                                51.53                               30.551
# 4                               51.589                               30.022
#
#   GDP growth (annual %) Population ages 0-14 (% of total)  \
# 0                   NaN                               NaN
# 1                   NaN                               NaN
# 2                   NaN                               NaN
# 3                   NaN                               NaN
# 4                   NaN                               NaN
#
#   Population ages 0-14, female Population ages 15-64 (% of total)  \
# 0                          NaN                                NaN
# 1                          NaN                                NaN
# 2                          NaN                                NaN
# 3                          NaN                                NaN
# 4                          NaN                                NaN
#
#   Population ages 15-64, female Population ages 15-64, male  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#   Population ages 15-64, total Population ages 65 and above (% of total)  \
# 0                          NaN                                   2.79831
# 1                          NaN                                   2.80813
# 2                          NaN                                   2.80411
# 3                          NaN                                   2.78617
# 4                          NaN                                   2.75422
#
#   Population ages 65 and above, female Population, female  \
# 0                               115755                NaN
# 1                               118864                NaN
# 2                               121786                NaN
# 3                               124431                NaN
# 4                               126641                NaN
#
#   Population, female (% of total)
# 0                             NaN
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN

# %% [markdown]
# <b> changing the datatype of the columns </b>

# %%
df['Year']=df['Year'].astype('int')
categorical_col=df.iloc[:,4:].describe(include='O').columns

for i in categorical_col:
    df[i]=df[i].astype('float')

# %% [markdown]
# # Imputation

# %% [markdown]
# ![Missing%20values.PNG](attachment:Missing%20values.PNG)

# %% [markdown]
# <b>Imputing the Life_expectancy column:</b>

# %% [markdown]
# Removing the country which doesn't have data for all years(1960 - 2016)

# %%
dum=pd.unique(df[(df['Life_expectancy'].isna()) & (df['Fertility_rate'].isna()) &
                 (df['Year'].isin([i for i in range(1960,2015)]))]['Country Name'])
df=df[~df['Country Name'].isin(dum)]

# %%
# Country Name with null life Expectany value
null_life_exp=pd.unique(df[df['Life_expectancy'].isna()]['Country Name'])

# %%
plt.plot(pd.unique(df['Year']),df[df['Country Name'].isin(null_life_exp)]['Life_expectancy'])
plt.title("Life_expectancy Before Imputataion")
# Out:
# Text(0.5, 1.0, 'Life_expectancy Before Imputataion')

# %% [markdown]
# Since there is a trend we can cubic interpolation for time series data

# %%
index=df[df['Country Name'].isin(null_life_exp)]['Life_expectancy'].index
df.loc[index,'Life_expectancy']=df[df['Country Name'].isin(null_life_exp)]['Life_expectancy'].interpolate(method='cubic')
df.loc[index,'Life_expectancy']=df[df['Country Name'].isin(null_life_exp)]['Life_expectancy'].interpolate(method='linear',limit_direction="both")
plt.plot(pd.unique(df['Year']),df[df['Country Name'].isin(null_life_exp)]['Life_expectancy'])
plt.title("Life_expectancy After Imputataion")
# Out:
# Text(0.5, 1.0, 'Life_expectancy After Imputataion')

# %% [markdown]
# <b>Imputing the  Fertility_rate column:</b>

# %%
null_fertility=pd.unique(df[df['Fertility_rate'].isna()]['Country Name'])

# %%
plt.plot(pd.unique(df['Year']),df[df['Country Name'].isin(null_fertility)]['Fertility_rate'])
plt.title("Fertility_rate Before Imputataion")
# Out:
# Text(0.5, 1.0, 'Fertility_rate Before Imputataion')

# %%
index=df[df['Country Name'].isin(null_fertility)]['Fertility_rate'].index
df.loc[index,'Fertility_rate']=df[df['Country Name'].isin(null_fertility)]['Fertility_rate'].interpolate(method='cubic')

plt.plot(pd.unique(df['Year']),df[df['Country Name'].isin(null_fertility)]['Fertility_rate'])
plt.title("Fertility_rate After Imputataion")
# Out:
# Text(0.5, 1.0, 'Fertility_rate After Imputataion')

# %% [markdown]
# <b>Imputing the  Total_population column:</b>

# %%
null_total_population=pd.unique(df[df['Total_Population'].isna()]['Country Name'])
null_total_population
# Out:
# array(['Eritrea', 'Kuwait'], dtype=object)

# %%
plt.plot(pd.unique(df['Year']),df[df['Country Name']==null_total_population[1]]['Total_Population'])
plt.title("Total Population for Kuwait before Imputaion")
# Out:
# Text(0.5, 1.0, 'Total Population for Kuwait before Imputaion')

# %% [markdown]
# For Kuwait since we have before and after data points for interpolation we can use cubic interpolation

# %%
index=df[df['Country Name']==null_total_population[1]]['Total_Population'].index
df.loc[index,'Total_Population']=df[df['Country Name']==null_total_population[1]]['Total_Population'].interpolate(method='cubic')

plt.plot(pd.unique(df['Year']),df[df['Country Name']==null_total_population[1]]['Total_Population'])
plt.title("Total Population for Kuwait After Imputaion")
# Out:
# Text(0.5, 1.0, 'Total Population for Kuwait After Imputaion')

# %% [markdown]
# ----------------------------------------------------------<br>
# For Eritrea we have missing values in end segment so interpolation doesn't work<br>
# We can use population growth rate column to impute the end segment values since there is positive trend

# %%
plt.plot(pd.unique(df['Year']),df[df['Country Name']==null_total_population[0]]['Total_Population'])
plt.title("Total Population for Eritrea before Imputaion")
# Out:
# Text(0.5, 1.0, 'Total Population for Eritrea before Imputaion')

# %%
df[['Population_growth_rate(%)']]=df[['Population_growth_rate(%)']].fillna(method='ffill')

# %% [markdown]
# Since there is a positive trend in the Popualtion  we are imputing the population growth rate to Imputation.

# %%
df['dummy']=df['Total_Population']
while(len(df[df['dummy'].isna()])>0):
    val=np.where((df['dummy'].isna()),
        df['dummy'].shift(periods=1)*(1+(df['Population_growth_rate(%)']/100)),df['dummy'])
    df['dummy']=val
df['Total_Population']=df['dummy']
df.drop('dummy',axis=1,inplace=True)

# %%
plt.plot(pd.unique(df['Year']),df[df['Country Name']==null_total_population[0]]['Total_Population'])
plt.title("Total Population for Eritrea After Imputaion")
# Out:
# Text(0.5, 1.0, 'Total Population for Eritrea After Imputaion')

# %%
df.isnull().sum()
# Out:
# Region                                          0
# IncomeGroup                                     0
# Country Name                                    0
# Year                                            0
# Life_expectancy                                 0
# Total_Population                                0
# Population_growth_rate(%)                       0
# Fertility_rate                                  0
# Birth rate, crude (per 1,000 people)            0
# Death rate, crude (per 1,000 people)            0
# GDP growth (annual %)                        2560
# Population ages 0-14 (% of total)            1908
# Population ages 0-14, female                 1911
# Population ages 15-64 (% of total)           1906
# Population ages 15-64, female                1911
# Population ages 15-64, male                  1911
# Population ages 15-64, total                 1911
# Population ages 65 and above (% of total)       5
# Population ages 65 and above, female            8
# Population, female                           1911
# Population, female (% of total)              1908
# dtype: int64

# %% [markdown]
# <b>Renaming the column name for convenience</b>

# %%
df=df.rename(columns={'Birth rate, crude (per 1,000 people)':'Birth_rate','Death rate, crude (per 1,000 people)':'Death_rate',
                  'GDP growth (annual %)':'GDP_growth'})

# %%
df.head()
# Out:
#        Region IncomeGroup Country Name  Year  Life_expectancy  \
# 0  South Asia  Low income  Afghanistan  1960           32.292
# 1  South Asia  Low income  Afghanistan  1961           32.742
# 2  South Asia  Low income  Afghanistan  1962           33.185
# 3  South Asia  Low income  Afghanistan  1963           33.624
# 4  South Asia  Low income  Afghanistan  1964           34.060
#
#    Total_Population  Population_growth_rate(%)  Fertility_rate  Birth_rate  \
# 0         8996351.0                        0.0            7.45      51.279
# 1         9166764.0                        1.9            7.45      51.373
# 2         9345868.0                        2.0            7.45      51.457
# 3         9533954.0                        2.0            7.45      51.530
# 4         9731361.0                        2.1            7.45      51.589
#
#    Death_rate  GDP_growth  Population ages 0-14 (% of total)  \
# 0      32.219         NaN                                NaN
# 1      31.649         NaN                                NaN
# 2      31.093         NaN                                NaN
# 3      30.551         NaN                                NaN
# 4      30.022         NaN                                NaN
#
#    Population ages 0-14, female  Population ages 15-64 (% of total)  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
#
#    Population ages 15-64, female  Population ages 15-64, male  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#    Population ages 15-64, total  Population ages 65 and above (% of total)  \
# 0                           NaN                                   2.798308
# 1                           NaN                                   2.808131
# 2                           NaN                                   2.804113
# 3                           NaN                                   2.786171
# 4                           NaN                                   2.754223
#
#    Population ages 65 and above, female  Population, female  \
# 0                              115755.0                 NaN
# 1                              118864.0                 NaN
# 2                              121786.0                 NaN
# 3                              124431.0                 NaN
# 4                              126641.0                 NaN
#
#    Population, female (% of total)
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %% [markdown]
# ## Feature Engineering :

# %% [markdown]
# <b> Converting crude birth rate of factor 1000 to distinct value <b>

# %%
val=np.round(df['Total_Population']*df['Birth_rate']/1000)
df.insert(loc=8, column='Total_births', value=val)
df.head()
# Out:
#        Region IncomeGroup Country Name  Year  Life_expectancy  \
# 0  South Asia  Low income  Afghanistan  1960           32.292
# 1  South Asia  Low income  Afghanistan  1961           32.742
# 2  South Asia  Low income  Afghanistan  1962           33.185
# 3  South Asia  Low income  Afghanistan  1963           33.624
# 4  South Asia  Low income  Afghanistan  1964           34.060
#
#    Total_Population  Population_growth_rate(%)  Fertility_rate  Total_births  \
# 0         8996351.0                        0.0            7.45      461324.0
# 1         9166764.0                        1.9            7.45      470924.0
# 2         9345868.0                        2.0            7.45      480910.0
# 3         9533954.0                        2.0            7.45      491285.0
# 4         9731361.0                        2.1            7.45      502031.0
#
#    Birth_rate  Death_rate  GDP_growth  Population ages 0-14 (% of total)  \
# 0      51.279      32.219         NaN                                NaN
# 1      51.373      31.649         NaN                                NaN
# 2      51.457      31.093         NaN                                NaN
# 3      51.530      30.551         NaN                                NaN
# 4      51.589      30.022         NaN                                NaN
#
#    Population ages 0-14, female  Population ages 15-64 (% of total)  \
# 0                           NaN                                 NaN
# 1                           NaN                                 NaN
# 2                           NaN                                 NaN
# 3                           NaN                                 NaN
# 4                           NaN                                 NaN
#
#    Population ages 15-64, female  Population ages 15-64, male  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
#
#    Population ages 15-64, total  Population ages 65 and above (% of total)  \
# 0                           NaN                                   2.798308
# 1                           NaN                                   2.808131
# 2                           NaN                                   2.804113
# 3                           NaN                                   2.786171
# 4                           NaN                                   2.754223
#
#    Population ages 65 and above, female  Population, female  \
# 0                              115755.0                 NaN
# 1                              118864.0                 NaN
# 2                              121786.0                 NaN
# 3                              124431.0                 NaN
# 4                              126641.0                 NaN
#
#    Population, female (% of total)
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %% [markdown]
# <b> Converting crude Death rate of factor 1000 to distinct value <b>

# %%
val=np.round(df['Total_Population']*df['Death_rate']/1000)
df.insert(loc=9, column='Total_deaths', value=val)
df.head()
# Out:
#        Region IncomeGroup Country Name  Year  Life_expectancy  \
# 0  South Asia  Low income  Afghanistan  1960           32.292
# 1  South Asia  Low income  Afghanistan  1961           32.742
# 2  South Asia  Low income  Afghanistan  1962           33.185
# 3  South Asia  Low income  Afghanistan  1963           33.624
# 4  South Asia  Low income  Afghanistan  1964           34.060
#
#    Total_Population  Population_growth_rate(%)  Fertility_rate  Total_births  \
# 0         8996351.0                        0.0            7.45      461324.0
# 1         9166764.0                        1.9            7.45      470924.0
# 2         9345868.0                        2.0            7.45      480910.0
# 3         9533954.0                        2.0            7.45      491285.0
# 4         9731361.0                        2.1            7.45      502031.0
#
#    Total_deaths  Birth_rate  Death_rate  GDP_growth  \
# 0      289853.0      51.279      32.219         NaN
# 1      290119.0      51.373      31.649         NaN
# 2      290591.0      51.457      31.093         NaN
# 3      291272.0      51.530      30.551         NaN
# 4      292155.0      51.589      30.022         NaN
#
#    Population ages 0-14 (% of total)  Population ages 0-14, female  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    Population ages 15-64 (% of total)  Population ages 15-64, female  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
#
#    Population ages 15-64, male  Population ages 15-64, total  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    Population ages 65 and above (% of total)  \
# 0                                   2.798308
# 1                                   2.808131
# 2                                   2.804113
# 3                                   2.786171
# 4                                   2.754223
#
#    Population ages 65 and above, female  Population, female  \
# 0                              115755.0                 NaN
# 1                              118864.0                 NaN
# 2                              121786.0                 NaN
# 3                              124431.0                 NaN
# 4                              126641.0                 NaN
#
#    Population, female (% of total)
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %% [markdown]
# <b> creating a new column Net Migration:</b><br><br>
# Total_population diff from previous year= Natural_Increase + Net Migration <br><br>
#         Natural_increase= total_births - total_deaths<br>
# <br>
# Net Migration = Total_population diff from previous year - Natural_Increase<br>

# %%
Natural_Increase= df['Total_births']-df['Total_deaths']
Total_pop_diff_prev_year=df.groupby(['Country Name'])['Total_Population'].diff().fillna(0)
Net_Migration=Total_pop_diff_prev_year-Natural_Increase
df.insert(loc=10, column='Net_Migration', value=Net_Migration)
df.loc[df['Year'] ==1960, ['Net_Migration']] = 0

# %%
df.head()
# Out:
#        Region IncomeGroup Country Name  Year  Life_expectancy  \
# 0  South Asia  Low income  Afghanistan  1960           32.292
# 1  South Asia  Low income  Afghanistan  1961           32.742
# 2  South Asia  Low income  Afghanistan  1962           33.185
# 3  South Asia  Low income  Afghanistan  1963           33.624
# 4  South Asia  Low income  Afghanistan  1964           34.060
#
#    Total_Population  Population_growth_rate(%)  Fertility_rate  Total_births  \
# 0         8996351.0                        0.0            7.45      461324.0
# 1         9166764.0                        1.9            7.45      470924.0
# 2         9345868.0                        2.0            7.45      480910.0
# 3         9533954.0                        2.0            7.45      491285.0
# 4         9731361.0                        2.1            7.45      502031.0
#
#    Total_deaths  Net_Migration  Birth_rate  Death_rate  GDP_growth  \
# 0      289853.0            0.0      51.279      32.219         NaN
# 1      290119.0       -10392.0      51.373      31.649         NaN
# 2      290591.0       -11215.0      51.457      31.093         NaN
# 3      291272.0       -11927.0      51.530      30.551         NaN
# 4      292155.0       -12469.0      51.589      30.022         NaN
#
#    Population ages 0-14 (% of total)  Population ages 0-14, female  \
# 0                                NaN                           NaN
# 1                                NaN                           NaN
# 2                                NaN                           NaN
# 3                                NaN                           NaN
# 4                                NaN                           NaN
#
#    Population ages 15-64 (% of total)  Population ages 15-64, female  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
#
#    Population ages 15-64, male  Population ages 15-64, total  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    Population ages 65 and above (% of total)  \
# 0                                   2.798308
# 1                                   2.808131
# 2                                   2.804113
# 3                                   2.786171
# 4                                   2.754223
#
#    Population ages 65 and above, female  Population, female  \
# 0                              115755.0                 NaN
# 1                              118864.0                 NaN
# 2                              121786.0                 NaN
# 3                              124431.0                 NaN
# 4                              126641.0                 NaN
#
#    Population, female (% of total)
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10830 entries, 0 to 14990
# Data columns (total 24 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Region                                     10830 non-null  object
#  1   IncomeGroup                                10830 non-null  object
#  2   Country Name                               10830 non-null  object
#  3   Year                                       10830 non-null  int32
#  4   Life_expectancy                            10830 non-null  float64
#  5   Total_Population                           10830 non-null  float64
#  6   Population_growth_rate(%)                  10830 non-null  float64
#  7   Fertility_rate                             10830 non-null  float64
#  8   Total_births                               10830 non-null  float64
#  9   Total_deaths                               10830 non-null  float64
#  10  Net_Migration                              10830 non-null  float64
#  11  Birth_rate                                 10830 non-null  float64
#  12  Death_rate                                 10830 non-null  float64
#  13  GDP_growth                                 8270 non-null   float64
#  14  Population ages 0-14 (% of total)          8922 non-null   float64
#  15  Population ages 0-14, female               8919 non-null   float64
#  16  Population ages 15-64 (% of total)         8924 non-null   float64
#  17  Population ages 15-64, female              8919 non-null   float64
#  18  Population ages 15-64, male                8919 non-null   float64
#  19  Population ages 15-64, total               8919 non-null   float64
#  20  Population ages 65 and above (% of total)  10825 non-null  float64
#  21  Population ages 65 and above, female       10822 non-null  float64
#  22  Population, female                         8919 non-null   float64
#  23  Population, female (% of total)            8922 non-null   float64
# dtypes: float64(20), int32(1), object(3)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Feature Selection:

# %% [markdown]
# <b> Feature Selection for india </b>

# %%
columns=['Year','Life_expectancy','Total_Population','Fertility_rate']

# %%
df1=df[df['Country Name']=='India'][columns]

# %%
for i in df1.columns[1:]:
    acf = smt.graphics.plot_acf(df1[i], lags=40 , alpha=0.05,title=i)
    acf.show()

# %% [markdown]
# Statestic test for auto correlation using dutbin_watson test

# %%
from statsmodels.stats.stattools import durbin_watson
out = durbin_watson(df1.iloc[:,1:])

# %%
for col,val in zip(df1.columns[1:],out):
    print(col,' : ',round(val,4))
# Out:
# Life_expectancy  :  0.0001
# Total_Population  :  0.0003
# Fertility_rate  :  0.0002

# %% [markdown]
#  All Values are less than 2 so we can say all columns are positive correlated

# %% [markdown]
# ## VAC- Vector Auto Regression

# %% [markdown]
# ### Testing Causation using Granger’s Causality Test

# %% [markdown]
# <p>
# Null Hypothesis      : Variable X does not Cause Varible Y <br>
# Alternate HYpothesis : Varibel X causes Variable Y
#  </p>

# %%
fig, axs = plt.subplots(3)
axs[0].plot(df1['Year'],df1['Life_expectancy'])
axs[1].plot(df1['Year'],df1['Fertility_rate'])
axs[2].plot(df1['Year'],df1['Total_Population'])

# %%
from statsmodels.tsa.stattools import grangercausalitytests
maxlag=12
test = 'ssr_chi2test'
def grangers_causation_matrix(data, variables, test='ssr_chi2test', verbose=False):    
    """Check Granger Causality of all possible combinations of the Time series.
    The rows are the response variable, columns are predictors. The values in the table 
    are the P-Values. P-Values lesser than the significance level (0.05), implies 
    the Null Hypothesis that the coefficients of the corresponding past values is 
    zero, that is, the X does not cause Y can be rejected.

    data      : pandas dataframe containing the time series variables
    variables : list containing names of the time series variables.
    """
    df2 = pd.DataFrame(np.zeros((len(variables), len(variables))), columns=variables, index=variables)
    for c in df2.columns:
        for r in df2.index:
            test_result = grangercausalitytests(data[[r, c]], maxlag=maxlag, verbose=False)
            p_values = [round(test_result[i+1][0][test][1],4) for i in range(maxlag)]
            if verbose: print(f'Y = {r}, X = {c}, P Values = {p_values}')
            min_p_value = np.min(p_values)
            df2.loc[r, c] = min_p_value
    df2.columns = [var + '_x' for var in variables]
    df2.index = [var + '_y' for var in variables]
    return df2

grangers_causation_matrix(df1, variables = df1.columns)
# Out:
#                     Year_x  Life_expectancy_x  Total_Population_x  \
# Year_y              0.0000                1.0                 1.0
# Life_expectancy_y   0.0614                1.0                 0.0
# Total_Population_y  0.0000                0.0                 1.0
# Fertility_rate_y    0.0000                0.0                 0.0
#
#                     Fertility_rate_x
# Year_y                           1.0
# Life_expectancy_y                0.0
# Total_Population_y               0.0
# Fertility_rate_y                 1.0

# %% [markdown]
# ### Train Test Split

# %%
column=['Life_expectancy','Total_Population','Fertility_rate']

# %%
X_train=df1[df1['Year']<2016][column]
y_train=df1[df1['Year']<2016]['Year']
X_test=df1[df1['Year']>=2016][column]
y_test=df1[df1['Year']>=2016]['Year']

# %% [markdown]
# ### Checking whether the columns are stationary or not

# %% [markdown]
# Null Hypothesis: Data has unit root. Non Stationary<br>
# Alternate Hypothesis: Data does not have unit root. Stationary

# %%
from statsmodels.tsa.stattools import adfuller
def adfuller_test(series, signif=0.05, name='', verbose=False):
    """Perform ADFuller to test for Stationarity of given series and print report"""
    r = adfuller(series, autolag='AIC')
    output = {'test_statistic':round(r[0], 4), 'pvalue':round(r[1], 4), 'n_lags':round(r[2], 4), 'n_obs':r[3]}
    p_value = output['pvalue'] 
    def adjust(val, length= 6): return str(val).ljust(length)

    # Print Summary
    print(f'    Augmented Dickey-Fuller Test on "{name}"', "\n   ", '-'*47)
    print(f' Null Hypothesis: Data has unit root. Non-Stationary.')
    print(f' Significance Level    = {signif}')
    print(f' Test Statistic        = {output["test_statistic"]}')
    print(f' No. Lags Chosen       = {output["n_lags"]}')

    for key,val in r[4].items():
        print(f' Critical value {adjust(key)} = {round(val, 3)}')

    if p_value <= signif:
        print(f" => P-Value = {p_value}. Rejecting Null Hypothesis.")
        print(f" => Series is Stationary.")
    else:
        print(f" => P-Value = {p_value}. Weak evidence to reject the Null Hypothesis.")
        print(f" => Series is Non-Stationary.")

# %%
# ADF Test on each column
for name, column in X_train.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Life_expectancy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.6736
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.575
#  Critical value 5%     = -2.924
#  Critical value 10%    = -2.6
#  => P-Value = 0.0787. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total_Population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.8063
#  No. Lags Chosen       = 9
#  Critical value 1%     = -3.581
#  Critical value 5%     = -2.927
#  Critical value 10%    = -2.602
#  => P-Value = 0.3773. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Fertility_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.6614
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.589
#  Critical value 5%     = -2.93
#  Critical value 10%    = -2.603
#  => P-Value = 0.0047. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# Stationary means there is a no trend over the years or the mean and median does not change over the years
# But the all columns are non stationary except Fertility rate Which means fertiltiy rate is stable throught out the years

# %% [markdown]
# ### Changing non stationary to stationary

# %%
# 1st difference
X_train_differenced = X_train.diff().dropna()

# %%
# ADF Test on each column of 1st Differences Dataframe
for name, column in X_train_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Life_expectancy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.5757
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.566
#  Critical value 5%     = -2.92
#  Critical value 10%    = -2.598
#  => P-Value = 0.8764. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total_Population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.9295
#  No. Lags Chosen       = 8
#  Critical value 1%     = -3.581
#  Critical value 5%     = -2.927
#  Critical value 10%    = -2.602
#  => P-Value = 0.3183. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Fertility_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.0352
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.575
#  Critical value 5%     = -2.924
#  Critical value 10%    = -2.6
#  => P-Value = 0.2713. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
# second Differnce

X_train_differenced = X_train_differenced.diff().dropna()

# %%
# ADF Test on each column of 2nd Differences Dataframe
for name, column in X_train_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Life_expectancy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.0599
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.566
#  Critical value 5%     = -2.92
#  Critical value 10%    = -2.598
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total_Population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -0.1243
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.581
#  Critical value 5%     = -2.927
#  Critical value 10%    = -2.602
#  => P-Value = 0.947. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Fertility_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.4479
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.597
#  Critical value 5%     = -2.933
#  Critical value 10%    = -2.605
#  => P-Value = 0.5591. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
# Third Difference

X_train_differenced = X_train_differenced.diff().dropna()

# %%
# ADF Test on each column of 3rd Differences Dataframe
for name, column in X_train_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Life_expectancy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.6783
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.575
#  Critical value 5%     = -2.924
#  Critical value 10%    = -2.6
#  => P-Value = 0.0001. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total_Population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.7207
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.581
#  Critical value 5%     = -2.927
#  Critical value 10%    = -2.602
#  => P-Value = 0.0038. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Fertility_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -4.3863
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.601
#  Critical value 5%     = -2.935
#  Critical value 10%    = -2.606
#  => P-Value = 0.0003. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %% [markdown]
# So after the third differnce all columns have become stationary

# %%
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
model = VAR(X_train_differenced)
x = model.select_order(maxlags=12)
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Lag 3 is best suited for VAR because there is fluctuation in those lags

# %%
model = VAR(X_train_differenced)
results = model.fit(maxlags=15, ic='aic')
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 28, Jul, 2020
# Time:                     19:14:55
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -102.252
# Nobs:                     38.0000    HQIC:                  -106.083
# Log likelihood:           2032.03    FPE:               -8.29500e-48
# AIC:                     -108.199    Det(Omega_mle):    -7.67944e-49
# --------------------------------------------------------------------
# Results for equation Life_expectancy
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                       -0.003857         0.000535           -7.205           0.000
# L1.Life_expectancy           0.791645         0.014113           56.093           0.000
# L1.Total_Population         -0.000000         0.000000           -7.042           0.000
# L1.Fertility_rate            0.095738              NAN              NAN             NAN
# L2.Life_expectancy          -0.390323         0.039077           -9.989           0.000
# L2.Total_Population          0.000000              NAN              NAN             NAN
# L2.Fertility_rate            0.457959         0.218641            2.095           0.036
# L3.Life_expectancy           0.481331              NAN              NAN             NAN
# L3.Total_Population         -0.000000         0.000000          -15.210           0.000
# L3.Fertility_rate            1.337958         0.277307            4.825           0.000
# L4.Life_expectancy          -0.061072         0.032513           -1.878           0.060
# L4.Total_Population          0.000000              NAN              NAN             NAN
# L4.Fertility_rate            0.301900              NAN              NAN             NAN
# L5.Life_expectancy           0.104899         0.010055           10.433           0.000
# L5.Total_Population         -0.000000              NAN              NAN             NAN
# L5.Fertility_rate           -0.123295         0.292055           -0.422           0.673
# L6.Life_expectancy           0.378256         0.031353           12.064           0.000
# L6.Total_Population         -0.000000              NAN              NAN             NAN
# L6.Fertility_rate            1.424620              NAN              NAN             NAN
# L7.Life_expectancy          -0.137983         0.029735           -4.640           0.000
# L7.Total_Population          0.000000              NAN              NAN             NAN
# L7.Fertility_rate            0.093459              NAN              NAN             NAN
# L8.Life_expectancy          -0.148084              NAN              NAN             NAN
# L8.Total_Population         -0.000000              NAN              NAN             NAN
# L8.Fertility_rate            0.725535         0.203429            3.567           0.000
# L9.Life_expectancy           0.115153              NAN              NAN             NAN
# L9.Total_Population          0.000000              NAN              NAN             NAN
# L9.Fertility_rate            0.010569              NAN              NAN             NAN
# L10.Life_expectancy         -0.771836              NAN              NAN             NAN
# L10.Total_Population        -0.000000         0.000000          -10.977           0.000
# L10.Fertility_rate           1.668986         0.121085           13.784           0.000
# L11.Life_expectancy          0.497225         0.022268           22.329           0.000
# L11.Total_Population         0.000000         0.000000            1.590           0.112
# L11.Fertility_rate           1.071879         0.157137            6.821           0.000
# L12.Life_expectancy         -0.334544              NAN              NAN             NAN
# L12.Total_Population        -0.000000              NAN              NAN             NAN
# L12.Fertility_rate           0.914764              NAN              NAN             NAN
# L13.Life_expectancy          0.065087         0.018782            3.465           0.001
# L13.Total_Population        -0.000000              NAN              NAN             NAN
# L13.Fertility_rate           0.303752              NAN              NAN             NAN
# L14.Life_expectancy         -0.529153              NAN              NAN             NAN
# L14.Total_Population         0.000000              NAN              NAN             NAN
# L14.Fertility_rate          -0.154888              NAN              NAN             NAN
# L15.Life_expectancy          0.602560              NAN              NAN             NAN
# L15.Total_Population        -0.000000              NAN              NAN             NAN
# L15.Fertility_rate          -1.153195              NAN              NAN             NAN
# =======================================================================================
#
# Results for equation Total_Population
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                   -47641.675324      3552.244886          -13.412           0.000
# L1.Life_expectancy     5565197.855430     93643.125742           59.430           0.000
# L1.Total_Population          0.957759         0.024804           38.613           0.000
# L1.Fertility_rate     -2835301.256989              NAN              NAN             NAN
# L2.Life_expectancy    -3733768.913687    259282.487295          -14.400           0.000
# L2.Total_Population         -0.976608              NAN              NAN             NAN
# L2.Fertility_rate       377930.086794   1450723.691931            0.261           0.794
# L3.Life_expectancy     1576127.229798              NAN              NAN             NAN
# L3.Total_Population         -0.366571         0.081298           -4.509           0.000
# L3.Fertility_rate      5080443.730839   1839984.214143            2.761           0.006
# L4.Life_expectancy    -3351798.227231    215730.813947          -15.537           0.000
# L4.Total_Population          0.801579              NAN              NAN             NAN
# L4.Fertility_rate     -1079659.310708              NAN              NAN             NAN
# L5.Life_expectancy       53804.329534     66716.615780            0.806           0.420
# L5.Total_Population         -1.939773              NAN              NAN             NAN
# L5.Fertility_rate     -1948461.811917   1937840.539464           -1.005           0.315
# L6.Life_expectancy     3687169.826258    208032.340841           17.724           0.000
# L6.Total_Population          1.047073              NAN              NAN             NAN
# L6.Fertility_rate      8858860.674754              NAN              NAN             NAN
# L7.Life_expectancy      258785.335852    197299.060326            1.312           0.190
# L7.Total_Population         -1.234431              NAN              NAN             NAN
# L7.Fertility_rate      1496566.153886              NAN              NAN             NAN
# L8.Life_expectancy    -2251589.001176              NAN              NAN             NAN
# L8.Total_Population          0.744187              NAN              NAN             NAN
# L8.Fertility_rate       989578.357625   1349789.709975            0.733           0.463
# L9.Life_expectancy     5186539.541634              NAN              NAN             NAN
# L9.Total_Population         -0.596887              NAN              NAN             NAN
# L9.Fertility_rate     -2850155.061771              NAN              NAN             NAN
# L10.Life_expectancy    -772662.280697              NAN              NAN             NAN
# L10.Total_Population        -0.046934         0.065147           -0.720           0.471
# L10.Fertility_rate     6881533.783509    803425.642579            8.565           0.000
# L11.Life_expectancy    2468673.727657    147755.045551           16.708           0.000
# L11.Total_Population         0.174646         0.076921            2.270           0.023
# L11.Fertility_rate     1698888.563977   1042638.100699            1.629           0.103
# L12.Life_expectancy   -2937279.803872              NAN              NAN             NAN
# L12.Total_Population        -0.667815              NAN              NAN             NAN
# L12.Fertility_rate      834285.349890              NAN              NAN             NAN
# L13.Life_expectancy     535438.773189    124619.410786            4.297           0.000
# L13.Total_Population         1.208725              NAN              NAN             NAN
# L13.Fertility_rate     4512964.924928              NAN              NAN             NAN
# L14.Life_expectancy   -1171430.129000              NAN              NAN             NAN
# L14.Total_Population        -0.751698              NAN              NAN             NAN
# L14.Fertility_rate     2547975.645170              NAN              NAN             NAN
# L15.Life_expectancy    4329789.114499              NAN              NAN             NAN
# L15.Total_Population         0.268454              NAN              NAN             NAN
# L15.Fertility_rate    -8260443.265902              NAN              NAN             NAN
# =======================================================================================
#
# Results for equation Fertility_rate
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                       -0.001354         0.000316           -4.282           0.000
# L1.Life_expectancy           0.116836         0.008335           14.018           0.000
# L1.Total_Population         -0.000000         0.000000          -16.310           0.000
# L1.Fertility_rate           -0.350542              NAN              NAN             NAN
# L2.Life_expectancy           0.154702         0.023078            6.704           0.000
# L2.Total_Population         -0.000000              NAN              NAN             NAN
# L2.Fertility_rate           -0.012192         0.129123           -0.094           0.925
# L3.Life_expectancy          -0.275700              NAN              NAN             NAN
# L3.Total_Population          0.000000         0.000000            7.953           0.000
# L3.Fertility_rate            0.316843         0.163770            1.935           0.053
# L4.Life_expectancy           0.197113         0.019201           10.266           0.000
# L4.Total_Population         -0.000000              NAN              NAN             NAN
# L4.Fertility_rate           -0.198964              NAN              NAN             NAN
# L5.Life_expectancy          -0.144852         0.005938          -24.393           0.000
# L5.Total_Population          0.000000              NAN              NAN             NAN
# L5.Fertility_rate            0.515007         0.172480            2.986           0.003
# L6.Life_expectancy           0.024644         0.018516            1.331           0.183
# L6.Total_Population         -0.000000              NAN              NAN             NAN
# L6.Fertility_rate           -0.539244              NAN              NAN             NAN
# L7.Life_expectancy          -0.362801         0.017561          -20.660           0.000
# L7.Total_Population          0.000000              NAN              NAN             NAN
# L7.Fertility_rate           -0.201781              NAN              NAN             NAN
# L8.Life_expectancy           0.498771              NAN              NAN             NAN
# L8.Total_Population         -0.000000              NAN              NAN             NAN
# L8.Fertility_rate           -0.079812         0.120140           -0.664           0.506
# L9.Life_expectancy          -0.360425              NAN              NAN             NAN
# L9.Total_Population          0.000000              NAN              NAN             NAN
# L9.Fertility_rate            0.134285              NAN              NAN             NAN
# L10.Life_expectancy          0.349346              NAN              NAN             NAN
# L10.Total_Population         0.000000         0.000000            4.711           0.000
# L10.Fertility_rate          -0.328540         0.071510           -4.594           0.000
# L11.Life_expectancy          0.172082         0.013151           13.085           0.000
# L11.Total_Population        -0.000000         0.000000           -8.367           0.000
# L11.Fertility_rate           0.104707         0.092801            1.128           0.259
# L12.Life_expectancy         -0.237552              NAN              NAN             NAN
# L12.Total_Population         0.000000              NAN              NAN             NAN
# L12.Fertility_rate          -0.402206              NAN              NAN             NAN
# L13.Life_expectancy          0.124920         0.011092           11.262           0.000
# L13.Total_Population        -0.000000              NAN              NAN             NAN
# L13.Fertility_rate           0.035847              NAN              NAN             NAN
# L14.Life_expectancy          0.137571              NAN              NAN             NAN
# L14.Total_Population         0.000000              NAN              NAN             NAN
# L14.Fertility_rate          -0.295642              NAN              NAN             NAN
# L15.Life_expectancy         -0.187587              NAN              NAN             NAN
# L15.Total_Population        -0.000000              NAN              NAN             NAN
# L15.Fertility_rate           0.627381              NAN              NAN             NAN
# =======================================================================================
#
# Correlation matrix of residuals
#                     Life_expectancy  Total_Population  Fertility_rate
# Life_expectancy            1.000000          0.828333       -0.130377
# Total_Population           0.828333          1.000000        0.038683
# Fertility_rate            -0.130377          0.038683        1.000000

# %%
results.plot_forecast(20)

# %%
# forecasting
nobs=50
pred = results.forecast(results.y, steps=nobs)
df_forecast = pd.DataFrame(pred, index=X_train.index[-nobs:], columns=X_train.columns + '_1d')
df_forecast.tail()
# inverting transformation
def invert_transformation(df_train, df_forecast, second_diff=True):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_1d'].cumsum()
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1d'].cumsum()
    return df_fc
# show inverted results in a dataframe
df_results = invert_transformation(X_train, df_forecast, second_diff=True)        
# df_results.loc[:, ['Total_Population','Life_expectancy','Fertility_rate']]

# %%
Final_forecast=df_results.copy()

# %%
val=[i for i in range(2016,2016+len(Final_forecast))]

Final_forecast.insert(loc=0, column='Year', value=val)

# %%
Final_forecast.drop(['Life_expectancy_1d','Total_Population_1d','Fertility_rate_1d'],axis=1,inplace=True)

# %%
Final_forecast.head(10)
# Out:
#       Year  Life_expectancy_forecast  Total_Population_forecast  \
# 6162  2016                 68.595972               1.324277e+09
# 6163  2017                 68.905971               1.339432e+09
# 6164  2018                 69.237931               1.354493e+09
# 6165  2019                 69.586057               1.369411e+09
# 6166  2020                 69.962029               1.384174e+09
# 6167  2021                 70.364209               1.398852e+09
# 6168  2022                 70.776160               1.413592e+09
# 6169  2023                 71.205542               1.428431e+09
# 6170  2024                 71.648645               1.443392e+09
# 6171  2025                 72.093570               1.458483e+09
#
#       Fertility_rate_forecast
# 6162                 2.312653
# 6163                 2.274823
# 6164                 2.229445
# 6165                 2.182658
# 6166                 2.138048
# 6167                 2.090961
# 6168                 2.054112
# 6169                 2.010385
# 6170                 1.967482
# 6171                 1.931825

# %% [markdown]
# ## Actual vs Forecast for year 2016 in india

# %%
X_test.head()
# Out:
#       Life_expectancy  Total_Population  Fertility_rate
# 6212            68.56      1.324171e+09           2.326

# %%
print('The percentage of differnce between Actual and Forecasted result for India:')
print("Life_expectancy  :",np.round((Final_forecast.iloc[0,1]-X_test.iloc[0,0])/X_test.iloc[0,0]*100,3),'%')
print("Total_Population :",np.round((Final_forecast.iloc[0,2]-X_test.iloc[0,1])/X_test.iloc[0,1]*100,3),'%')
print("Fertility_rate   :",np.round((Final_forecast.iloc[0,3]-X_test.iloc[0,2])/X_test.iloc[0,2]*100,3),'%')
# Out:
# The percentage of differnce between Actual and Forecasted result for India:
# Life_expectancy  : 0.052 %
# Total_Population : 0.008 %
# Fertility_rate   : -0.574 %

# %%
def forecast_accuracy(forecast, actual):
    mape = np.mean(np.abs(forecast - actual)/np.abs(actual))*100  # MAPE
    rmse = np.mean((forecast - actual)**2)**.5  # RMSE 
    return({'mape':mape,'rmse':rmse})

# %%
print(forecast_accuracy(Final_forecast.iloc[0,2],X_test.iloc[0,1]))
# Out:
# {'mape': 0.007944254303643223, 'rmse': 105195.53977775574}

# %%
df_final_actual=df[df['Country Name']=='India'][['Year','Total_Population']]
df_final_actual['Legend']='Actual'
df_final_forecast=pd.DataFrame(Final_forecast[['Year','Total_Population_forecast']])
df_final_forecast=df_final_forecast.rename(columns={'Total_Population_forecast':'Total_Population'})
df_final_forecast['Legend']='Forecast'
df_final=pd.concat([df_final_actual,df_final_forecast],ignore_index=True)


plt.figure(figsize=(9,7))
sns.lineplot(x='Year',y='Total_Population',data=df_final,hue='Legend',style='Legend',dashes=True)
plt.title('Forecast vs Actuals population for India')
plt.legend(loc='upper left', fontsize=18,title=None)
plt.show()

# %% [markdown]
# ## Population Prediction for Israel

# %%
df2=df[df['Country Name']=='Israel'][columns]
df2.head()
column=['Life_expectancy','Total_Population','Fertility_rate']

# %%
X_train=df2[df2['Year']<2016][column]
y_train=df2[df2['Year']<2016]['Year']
X_test=df2[df2['Year']>=2016][column]
y_test=df2[df2['Year']>=2016]['Year']

# %% [markdown]
# ## Stationarity Test

# %%
# ADF Test on each column
for name, column in X_train.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Life_expectancy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 0.7464
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.563
#  Critical value 5%     = -2.919
#  Critical value 10%    = -2.597
#  => P-Value = 0.9907. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total_Population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 2.3242
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.558
#  Critical value 5%     = -2.917
#  Critical value 10%    = -2.596
#  => P-Value = 0.999. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Fertility_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.7987
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.558
#  Critical value 5%     = -2.917
#  Critical value 10%    = -2.596
#  => P-Value = 0.3811. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %% [markdown]
# ### Changing Non stationary to stationary

# %%
# 1st difference
X_train_differenced = X_train.diff().dropna()

# %%
# ADF Test on each column of 1st Differences Dataframe
for name, column in X_train_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Life_expectancy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.3862
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.566
#  Critical value 5%     = -2.92
#  Critical value 10%    = -2.598
#  => P-Value = 0.0114. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total_Population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.174
#  No. Lags Chosen       = 0
#  Critical value 1%     = -3.558
#  Critical value 5%     = -2.917
#  Critical value 10%    = -2.596
#  => P-Value = 0.0215. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Fertility_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.9904
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.56
#  Critical value 5%     = -2.918
#  Critical value 10%    = -2.597
#  => P-Value = 0.0358. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
model = VAR(X_train_differenced)
x = model.select_order(maxlags=20)
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model = VAR(X_train_differenced)
results = model.fit(maxlags=17, ic='aic')
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 28, Jul, 2020
# Time:                     18:11:34
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -100.794
# Nobs:                     40.0000    HQIC:                  -104.514
# Log likelihood:           2100.15    FPE:               -1.47062e-46
# AIC:                     -106.621    Det(Omega_mle):    -1.47973e-47
# --------------------------------------------------------------------
# Results for equation Life_expectancy
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        0.508031              NAN              NAN             NAN
# L1.Life_expectancy          -0.608718         0.006748          -90.212           0.000
# L1.Total_Population         -0.000005         0.000000          -69.292           0.000
# L1.Fertility_rate           -8.256155         0.038141         -216.462           0.000
# L2.Life_expectancy           0.174605         0.004754           36.730           0.000
# L2.Total_Population          0.000009         0.000000          190.538           0.000
# L2.Fertility_rate           -0.663118         0.057869          -11.459           0.000
# L3.Life_expectancy          -0.034622         0.009404           -3.681           0.000
# L3.Total_Population         -0.000004              NAN              NAN             NAN
# L3.Fertility_rate           -0.031595         0.057613           -0.548           0.583
# L4.Life_expectancy          -0.500789         0.012941          -38.698           0.000
# L4.Total_Population          0.000005              NAN              NAN             NAN
# L4.Fertility_rate            0.274584              NAN              NAN             NAN
# L5.Life_expectancy           0.453179         0.013412           33.789           0.000
# L5.Total_Population         -0.000008         0.000000          -55.856           0.000
# L5.Fertility_rate           -0.158163         0.090150           -1.754           0.079
# L6.Life_expectancy          -0.039465         0.019062           -2.070           0.038
# L6.Total_Population          0.000016              NAN              NAN             NAN
# L6.Fertility_rate            1.149372         0.059572           19.294           0.000
# L7.Life_expectancy          -0.402532         0.017185          -23.424           0.000
# L7.Total_Population         -0.000012              NAN              NAN             NAN
# L7.Fertility_rate           -4.528074         0.011936         -379.367           0.000
# L8.Life_expectancy          -0.915019              NAN              NAN             NAN
# L8.Total_Population          0.000004              NAN              NAN             NAN
# L8.Fertility_rate           -3.170744         0.040805          -77.705           0.000
# L9.Life_expectancy           0.301473         0.005314           56.729           0.000
# L9.Total_Population         -0.000006              NAN              NAN             NAN
# L9.Fertility_rate           -1.107867         0.054083          -20.485           0.000
# L10.Life_expectancy          0.325888         0.006837           47.666           0.000
# L10.Total_Population         0.000012         0.000000          697.386           0.000
# L10.Fertility_rate           4.925503         0.056033           87.904           0.000
# L11.Life_expectancy          0.494815              NAN              NAN             NAN
# L11.Total_Population         0.000002              NAN              NAN             NAN
# L11.Fertility_rate           5.383630         0.086304           62.380           0.000
# L12.Life_expectancy         -0.303343              NAN              NAN             NAN
# L12.Total_Population        -0.000009         0.000000         -144.089           0.000
# L12.Fertility_rate          -2.601270              NAN              NAN             NAN
# L13.Life_expectancy          0.408939              NAN              NAN             NAN
# L13.Total_Population        -0.000003         0.000000          -29.632           0.000
# L13.Fertility_rate           3.006056         0.062900           47.791           0.000
# L14.Life_expectancy          0.796296         0.005478          145.373           0.000
# L14.Total_Population        -0.000001              NAN              NAN             NAN
# L14.Fertility_rate          -0.125223         0.049120           -2.549           0.011
# L15.Life_expectancy          0.403181         0.012884           31.293           0.000
# L15.Total_Population        -0.000002         0.000000          -40.565           0.000
# L15.Fertility_rate           3.565676              NAN              NAN             NAN
# =======================================================================================
#
# Results for equation Total_Population
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                   157743.740078              NAN              NAN             NAN
# L1.Life_expectancy       33265.822851       379.641565           87.624           0.000
# L1.Total_Population          0.761954         0.003968          192.042           0.000
# L1.Fertility_rate       346740.123442      2145.935183          161.580           0.000
# L2.Life_expectancy       77253.922936       267.460449          288.842           0.000
# L2.Total_Population         -0.450212         0.002523         -178.449           0.000
# L2.Fertility_rate      -586316.360121      3255.847096         -180.081           0.000
# L3.Life_expectancy        5157.262958       529.118229            9.747           0.000
# L3.Total_Population          0.684164              NAN              NAN             NAN
# L3.Fertility_rate       297970.734099      3241.447645           91.925           0.000
# L4.Life_expectancy       15378.538879       728.093067           21.122           0.000
# L4.Total_Population         -1.000753              NAN              NAN             NAN
# L4.Fertility_rate       337544.218526              NAN              NAN             NAN
# L5.Life_expectancy        4793.878989       754.590767            6.353           0.000
# L5.Total_Population          0.711119         0.007599           93.584           0.000
# L5.Fertility_rate       282918.083322      5072.048197           55.780           0.000
# L6.Life_expectancy       98324.123466      1072.500266           91.677           0.000
# L6.Total_Population         -0.740487              NAN              NAN             NAN
# L6.Fertility_rate       384717.850770      3351.693749          114.783           0.000
# L7.Life_expectancy       44129.503835       966.858314           45.642           0.000
# L7.Total_Population          0.083318              NAN              NAN             NAN
# L7.Fertility_rate      -338150.135630       671.541903         -503.543           0.000
# L8.Life_expectancy       47113.422016              NAN              NAN             NAN
# L8.Total_Population         -0.912108              NAN              NAN             NAN
# L8.Fertility_rate        52474.328338      2295.787601           22.857           0.000
# L9.Life_expectancy       42150.148584       298.996032          140.972           0.000
# L9.Total_Population          0.607203              NAN              NAN             NAN
# L9.Fertility_rate       460572.936390      3042.827863          151.363           0.000
# L10.Life_expectancy      46798.883090       384.665611          121.661           0.000
# L10.Total_Population         0.353184         0.000984          359.023           0.000
# L10.Fertility_rate      416160.571302      3152.554302          132.007           0.000
# L11.Life_expectancy     -21949.026616              NAN              NAN             NAN
# L11.Total_Population        -0.428987              NAN              NAN             NAN
# L11.Fertility_rate      194493.408139      4855.684017           40.055           0.000
# L12.Life_expectancy     -16246.000490              NAN              NAN             NAN
# L12.Total_Population        -0.526486         0.003588         -146.733           0.000
# L12.Fertility_rate     -124963.646053              NAN              NAN             NAN
# L13.Life_expectancy      -4949.345725              NAN              NAN             NAN
# L13.Total_Population        -0.674547         0.005343         -126.257           0.000
# L13.Fertility_rate     -138011.582478      3538.907907          -38.998           0.000
# L14.Life_expectancy      35311.782325       308.183635          114.580           0.000
# L14.Total_Population         0.679834              NAN              NAN             NAN
# L14.Fertility_rate      -58926.121359      2763.601895          -21.322           0.000
# L15.Life_expectancy      34654.531933       724.887764           47.807           0.000
# L15.Total_Population        -0.101375         0.002842          -35.674           0.000
# L15.Fertility_rate      298022.554399              NAN              NAN             NAN
# =======================================================================================
#
# Results for equation Fertility_rate
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                       -0.194222              NAN              NAN             NAN
# L1.Life_expectancy          -0.025972         0.000260         -100.051           0.000
# L1.Total_Population          0.000000         0.000000           37.773           0.000
# L1.Fertility_rate           -0.214576         0.001467         -146.237           0.000
# L2.Life_expectancy           0.004942         0.000183           27.022           0.000
# L2.Total_Population         -0.000000         0.000000           -7.975           0.000
# L2.Fertility_rate            0.133847         0.002226           60.122           0.000
# L3.Life_expectancy           0.025117         0.000362           69.425           0.000
# L3.Total_Population          0.000001              NAN              NAN             NAN
# L3.Fertility_rate           -0.087550         0.002216          -39.501           0.000
# L4.Life_expectancy           0.036403         0.000498           73.121           0.000
# L4.Total_Population         -0.000001              NAN              NAN             NAN
# L4.Fertility_rate           -0.223784              NAN              NAN             NAN
# L5.Life_expectancy           0.010135         0.000516           19.643           0.000
# L5.Total_Population          0.000000         0.000000           58.449           0.000
# L5.Fertility_rate           -0.157045         0.003468          -45.283           0.000
# L6.Life_expectancy           0.078925         0.000733          107.624           0.000
# L6.Total_Population         -0.000001              NAN              NAN             NAN
# L6.Fertility_rate           -0.193908         0.002292          -84.610           0.000
# L7.Life_expectancy           0.057912         0.000661           87.598           0.000
# L7.Total_Population          0.000001              NAN              NAN             NAN
# L7.Fertility_rate            0.531470         0.000459         1157.438           0.000
# L8.Life_expectancy           0.045943              NAN              NAN             NAN
# L8.Total_Population         -0.000001              NAN              NAN             NAN
# L8.Fertility_rate           -0.201168         0.001570         -128.150           0.000
# L9.Life_expectancy          -0.019054         0.000204          -93.199           0.000
# L9.Total_Population         -0.000000              NAN              NAN             NAN
# L9.Fertility_rate           -0.046421         0.002081          -22.311           0.000
# L10.Life_expectancy          0.049638         0.000263          188.720           0.000
# L10.Total_Population        -0.000000         0.000000         -388.172           0.000
# L10.Fertility_rate           0.022663         0.002156           10.514           0.000
# L11.Life_expectancy          0.006474              NAN              NAN             NAN
# L11.Total_Population         0.000000              NAN              NAN             NAN
# L11.Fertility_rate           0.016716         0.003320            5.035           0.000
# L12.Life_expectancy         -0.001454              NAN              NAN             NAN
# L12.Total_Population        -0.000000         0.000000          -72.440           0.000
# L12.Fertility_rate          -0.101034              NAN              NAN             NAN
# L13.Life_expectancy          0.001863              NAN              NAN             NAN
# L13.Total_Population        -0.000000         0.000000          -91.940           0.000
# L13.Fertility_rate          -0.013561         0.002420           -5.604           0.000
# L14.Life_expectancy          0.058921         0.000211          279.611           0.000
# L14.Total_Population        -0.000000              NAN              NAN             NAN
# L14.Fertility_rate           0.036093         0.001890           19.100           0.000
# L15.Life_expectancy          0.016870         0.000496           34.036           0.000
# L15.Total_Population         0.000000         0.000000          242.115           0.000
# L15.Fertility_rate           0.488345              NAN              NAN             NAN
# =======================================================================================
#
# Correlation matrix of residuals
#                     Life_expectancy  Total_Population  Fertility_rate
# Life_expectancy            1.000000         -0.699010        0.594363
# Total_Population          -0.699010          1.000000       -0.863689
# Fertility_rate             0.594363         -0.863689        1.000000

# %%
# forecasting
nobs=50
pred = results.forecast(results.y, steps=nobs)
df_forecast = pd.DataFrame(pred, index=X_train.index[-nobs:], columns=X_train.columns + '_1d')
df_forecast.tail()
# inverting transformation
def invert_transformation(df_train, df_forecast, second_diff=True):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_1d'].cumsum()
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1d'].cumsum()
    return df_fc
# show inverted results in a dataframe
df_results = invert_transformation(X_train, df_forecast, second_diff=True)        
# df_results.loc[:, ['Total_Population','Life_expectancy','Fertility_rate']]

# %%
 
Final_forecast=df_results.copy()
 
val=[i for i in range(2016,2016+len(Final_forecast))]

Final_forecast.insert(loc=0, column='Year', value=val)

Final_forecast.drop(['Life_expectancy_1d','Total_Population_1d','Fertility_rate_1d'],axis=1,inplace=True)

Final_forecast.head()
# Out:
#       Year  Life_expectancy_forecast  Total_Population_forecast  \
# 6504  2016                 81.237862               8.714384e+06
# 6505  2017                 80.452661               9.137443e+06
# 6506  2018                 80.758675               9.669316e+06
# 6507  2019                 81.933062               1.036792e+07
# 6508  2020                 84.016130               1.123672e+07
#
#       Fertility_rate_forecast
# 6504                 3.180576
# 6505                 3.290365
# 6506                 3.371927
# 6507                 3.419504
# 6508                 3.268079

# %%
print('The percentage of differnce between Actual and Forecasted result for Israel:')
# print("Life_expectancy  :",np.round((Final_forecast.iloc[0,1]-X_test.iloc[0,0])/X_test.iloc[0,0]*100,3),'%')
print("Total_Population :",np.round((Final_forecast.iloc[0,2]-X_test.iloc[0,1])/X_test.iloc[0,1]*100,3),'%')
# print("Fertility_rate   :",np.round((Final_forecast.iloc[0,3]-X_test.iloc[0,2])/X_test.iloc[0,2]*100,3),'%')
# Out:
# The percentage of differnce between Actual and Forecasted result for Israel:
# Total_Population : 1.97 %

# %%
df_final_actual=df[df['Country Name']=='Israel'][['Year','Total_Population']]
df_final_actual['Legend']='Actual'
df_final_forecast=pd.DataFrame(Final_forecast[['Year','Total_Population_forecast']])
df_final_forecast=df_final_forecast.rename(columns={'Total_Population_forecast':'Total_Population'})
df_final_forecast['Legend']='Forecast'
df_final=pd.concat([df_final_actual,df_final_forecast],ignore_index=True)


plt.figure(figsize=(9,7))
sns.lineplot(x='Year',y='Total_Population',data=df_final,hue='Legend',style='Legend',dashes=True)
plt.title('Forecast vs Actuals population for Israel')
plt.legend(loc='upper left', fontsize=18,title=None)
plt.show()

# %% [markdown]
# ## Population Prediction for Tanzania

# %%
df3=df[df['Country Name']=='Tanzania'][columns]
df3.head()
column=['Life_expectancy','Total_Population','Fertility_rate']

# %%
X_train=df3[df3['Year']<2016][column]
y_train=df3[df3['Year']<2016]['Year']
X_test=df3[df3['Year']>=2016][column]
y_test=df3[df3['Year']>=2016]['Year']

# %% [markdown]
# ### Stationarity Test

# %%
# ADF Test on each column
for name, column in X_train.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Life_expectancy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 0.8873
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.566
#  Critical value 5%     = -2.92
#  Critical value 10%    = -2.598
#  => P-Value = 0.9929. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total_Population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 3.4286
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.589
#  Critical value 5%     = -2.93
#  Critical value 10%    = -2.603
#  => P-Value = 1.0. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Fertility_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 1.5424
#  No. Lags Chosen       = 7
#  Critical value 1%     = -3.575
#  Critical value 5%     = -2.924
#  Critical value 10%    = -2.6
#  => P-Value = 0.9977. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %% [markdown]
# <b> Changing Non stationary to Stationary

# %%
# 1st difference
X_train_differenced = X_train.diff().dropna()

# %%
# ADF Test on each column of 1st Differences Dataframe
for name, column in X_train_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Life_expectancy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -2.3121
#  No. Lags Chosen       = 3
#  Critical value 1%     = -3.566
#  Critical value 5%     = -2.92
#  Critical value 10%    = -2.598
#  => P-Value = 0.1681. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total_Population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = 2.1211
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.593
#  Critical value 5%     = -2.932
#  Critical value 10%    = -2.604
#  => P-Value = 0.9988. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Fertility_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.4749
#  No. Lags Chosen       = 6
#  Critical value 1%     = -3.575
#  Critical value 5%     = -2.924
#  Critical value 10%    = -2.6
#  => P-Value = 0.5459. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
# second Differnce

X_train_differenced = X_train_differenced.diff().dropna()

# %%
# ADF Test on each column of 2nd Differences Dataframe
for name, column in X_train_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Life_expectancy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.8416
#  No. Lags Chosen       = 2
#  Critical value 1%     = -3.566
#  Critical value 5%     = -2.92
#  Critical value 10%    = -2.598
#  => P-Value = 0.36. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total_Population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.7852
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.597
#  Critical value 5%     = -2.933
#  Critical value 10%    = -2.605
#  => P-Value = 0.3878. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Fertility_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -1.9374
#  No. Lags Chosen       = 5
#  Critical value 1%     = -3.575
#  Critical value 5%     = -2.924
#  Critical value 10%    = -2.6
#  => P-Value = 0.3147. Weak evidence to reject the Null Hypothesis.
#  => Series is Non-Stationary.

# %%
# third Differnce

X_train_differenced = X_train_differenced.diff().dropna()

# %%
# ADF Test on each column of 3rd Differences Dataframe
for name, column in X_train_differenced.iteritems():
    adfuller_test(column, name=column.name)
    print('\n')
# Out:
#     Augmented Dickey-Fuller Test on "Life_expectancy"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.4944
#  No. Lags Chosen       = 1
#  Critical value 1%     = -3.566
#  Critical value 5%     = -2.92
#  Critical value 10%    = -2.598
#  => P-Value = 0.0081. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Total_Population"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -3.4427
#  No. Lags Chosen       = 11
#  Critical value 1%     = -3.601
#  Critical value 5%     = -2.935
#  Critical value 10%    = -2.606
#  => P-Value = 0.0096. Rejecting Null Hypothesis.
#  => Series is Stationary.
#
#
#     Augmented Dickey-Fuller Test on "Fertility_rate"
#     -----------------------------------------------
#  Null Hypothesis: Data has unit root. Non-Stationary.
#  Significance Level    = 0.05
#  Test Statistic        = -5.1706
#  No. Lags Chosen       = 4
#  Critical value 1%     = -3.575
#  Critical value 5%     = -2.924
#  Critical value 10%    = -2.6
#  => P-Value = 0.0. Rejecting Null Hypothesis.
#  => Series is Stationary.

# %%
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
model = VAR(X_train_differenced)
x = model.select_order(maxlags=12)
x.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
model = VAR(X_train_differenced)
results = model.fit(maxlags=15, ic='aic')
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Tue, 28, Jul, 2020
# Time:                     18:11:36
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -112.099
# Nobs:                     38.0000    HQIC:                  -115.930
# Log likelihood:           2219.11    FPE:               -4.39062e-52
# AIC:                     -118.046    Det(Omega_mle):    -4.06480e-53
# --------------------------------------------------------------------
# Results for equation Life_expectancy
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        0.002629              NAN              NAN             NAN
# L1.Life_expectancy           0.467053              NAN              NAN             NAN
# L1.Total_Population          0.000000              NAN              NAN             NAN
# L1.Fertility_rate           -0.938459              NAN              NAN             NAN
# L2.Life_expectancy           0.220040              NAN              NAN             NAN
# L2.Total_Population         -0.000002              NAN              NAN             NAN
# L2.Fertility_rate            1.582090         0.016455           96.146           0.000
# L3.Life_expectancy          -0.455740              NAN              NAN             NAN
# L3.Total_Population          0.000001         0.000000           78.093           0.000
# L3.Fertility_rate           -0.702779              NAN              NAN             NAN
# L4.Life_expectancy           0.095691              NAN              NAN             NAN
# L4.Total_Population          0.000000              NAN              NAN             NAN
# L4.Fertility_rate            0.082004              NAN              NAN             NAN
# L5.Life_expectancy           0.035265              NAN              NAN             NAN
# L5.Total_Population         -0.000000         0.000000           -9.166           0.000
# L5.Fertility_rate           -0.311015              NAN              NAN             NAN
# L6.Life_expectancy           0.083279              NAN              NAN             NAN
# L6.Total_Population         -0.000000         0.000000          -28.286           0.000
# L6.Fertility_rate           -0.252718              NAN              NAN             NAN
# L7.Life_expectancy          -0.395676              NAN              NAN             NAN
# L7.Total_Population         -0.000000              NAN              NAN             NAN
# L7.Fertility_rate            0.461861              NAN              NAN             NAN
# L8.Life_expectancy           0.084168              NAN              NAN             NAN
# L8.Total_Population          0.000002              NAN              NAN             NAN
# L8.Fertility_rate           -0.608776              NAN              NAN             NAN
# L9.Life_expectancy          -0.173224              NAN              NAN             NAN
# L9.Total_Population         -0.000002              NAN              NAN             NAN
# L9.Fertility_rate           -0.403278              NAN              NAN             NAN
# L10.Life_expectancy          0.627494              NAN              NAN             NAN
# L10.Total_Population         0.000002              NAN              NAN             NAN
# L10.Fertility_rate           0.781443              NAN              NAN             NAN
# L11.Life_expectancy          0.173368              NAN              NAN             NAN
# L11.Total_Population        -0.000001         0.000000          -30.413           0.000
# L11.Fertility_rate          -0.176010              NAN              NAN             NAN
# L12.Life_expectancy         -0.243663         0.014700          -16.575           0.000
# L12.Total_Population        -0.000000              NAN              NAN             NAN
# L12.Fertility_rate           0.701658              NAN              NAN             NAN
# L13.Life_expectancy          0.335213         0.002241          149.552           0.000
# L13.Total_Population         0.000002              NAN              NAN             NAN
# L13.Fertility_rate          -0.149692         0.057843           -2.588           0.010
# L14.Life_expectancy         -0.621730         0.009322          -66.694           0.000
# L14.Total_Population        -0.000002         0.000000         -719.899           0.000
# L14.Fertility_rate          -0.976061              NAN              NAN             NAN
# L15.Life_expectancy         -0.601132              NAN              NAN             NAN
# L15.Total_Population         0.000001              NAN              NAN             NAN
# L15.Fertility_rate          -0.189377              NAN              NAN             NAN
# =======================================================================================
#
# Results for equation Total_Population
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                     1367.762134              NAN              NAN             NAN
# L1.Life_expectancy     -444554.102938              NAN              NAN             NAN
# L1.Total_Population          1.621164              NAN              NAN             NAN
# L1.Fertility_rate       564266.318781              NAN              NAN             NAN
# L2.Life_expectancy      331806.900628              NAN              NAN             NAN
# L2.Total_Population         -1.688523              NAN              NAN             NAN
# L2.Fertility_rate      -253651.655850     10443.790908          -24.287           0.000
# L3.Life_expectancy     -209864.414671              NAN              NAN             NAN
# L3.Total_Population          0.720094         0.004940          145.763           0.000
# L3.Fertility_rate       435697.370322              NAN              NAN             NAN
# L4.Life_expectancy       18753.706310              NAN              NAN             NAN
# L4.Total_Population         -0.550214              NAN              NAN             NAN
# L4.Fertility_rate      1130519.798820              NAN              NAN             NAN
# L5.Life_expectancy     -249593.741903              NAN              NAN             NAN
# L5.Total_Population         -0.238582         0.006806          -35.054           0.000
# L5.Fertility_rate        34909.056008              NAN              NAN             NAN
# L6.Life_expectancy       64924.875858              NAN              NAN             NAN
# L6.Total_Population          1.083454         0.008113          133.553           0.000
# L6.Fertility_rate      -951435.086731              NAN              NAN             NAN
# L7.Life_expectancy      258254.546828              NAN              NAN             NAN
# L7.Total_Population         -1.321059              NAN              NAN             NAN
# L7.Fertility_rate       107532.484813              NAN              NAN             NAN
# L8.Life_expectancy      -90105.836569              NAN              NAN             NAN
# L8.Total_Population          2.025542              NAN              NAN             NAN
# L8.Fertility_rate       111633.736221              NAN              NAN             NAN
# L9.Life_expectancy      -34806.097433              NAN              NAN             NAN
# L9.Total_Population         -2.725322              NAN              NAN             NAN
# L9.Fertility_rate     -1838609.432479              NAN              NAN             NAN
# L10.Life_expectancy     258378.946972              NAN              NAN             NAN
# L10.Total_Population         2.343856              NAN              NAN             NAN
# L10.Fertility_rate     -268988.578146              NAN              NAN             NAN
# L11.Life_expectancy     127544.322086              NAN              NAN             NAN
# L11.Total_Population        -0.722524         0.011318          -63.840           0.000
# L11.Fertility_rate      409893.352247              NAN              NAN             NAN
# L12.Life_expectancy    -266087.323371      9330.161034          -28.519           0.000
# L12.Total_Population        -0.754820              NAN              NAN             NAN
# L12.Fertility_rate      -51631.379120              NAN              NAN             NAN
# L13.Life_expectancy     372441.708149      1422.618295          261.800           0.000
# L13.Total_Population         2.215075              NAN              NAN             NAN
# L13.Fertility_rate      715833.389822     36711.956952           19.499           0.000
# L14.Life_expectancy    -458368.651746      5916.648633          -77.471           0.000
# L14.Total_Population        -2.454671         0.001632        -1503.983           0.000
# L14.Fertility_rate      252017.681033              NAN              NAN             NAN
# L15.Life_expectancy    -104109.716893              NAN              NAN             NAN
# L15.Total_Population         1.195461              NAN              NAN             NAN
# L15.Fertility_rate     -844958.649025              NAN              NAN             NAN
# =======================================================================================
#
# Results for equation Fertility_rate
# =======================================================================================
#                           coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------------
# const                        0.000618              NAN              NAN             NAN
# L1.Life_expectancy          -0.134395              NAN              NAN             NAN
# L1.Total_Population          0.000000              NAN              NAN             NAN
# L1.Fertility_rate           -0.812838              NAN              NAN             NAN
# L2.Life_expectancy           0.253781              NAN              NAN             NAN
# L2.Total_Population         -0.000000              NAN              NAN             NAN
# L2.Fertility_rate           -0.240470         0.015483          -15.531           0.000
# L3.Life_expectancy          -0.110810              NAN              NAN             NAN
# L3.Total_Population         -0.000000         0.000000          -60.614           0.000
# L3.Fertility_rate            0.901943              NAN              NAN             NAN
# L4.Life_expectancy          -0.036207              NAN              NAN             NAN
# L4.Total_Population          0.000000              NAN              NAN             NAN
# L4.Fertility_rate           -0.148871              NAN              NAN             NAN
# L5.Life_expectancy          -0.031042              NAN              NAN             NAN
# L5.Total_Population          0.000000         0.000000           45.233           0.000
# L5.Fertility_rate            0.131295              NAN              NAN             NAN
# L6.Life_expectancy          -0.103419              NAN              NAN             NAN
# L6.Total_Population         -0.000000         0.000000          -30.605           0.000
# L6.Fertility_rate           -0.351487              NAN              NAN             NAN
# L7.Life_expectancy           0.124826              NAN              NAN             NAN
# L7.Total_Population         -0.000000              NAN              NAN             NAN
# L7.Fertility_rate            0.149748              NAN              NAN             NAN
# L8.Life_expectancy          -0.121303              NAN              NAN             NAN
# L8.Total_Population          0.000000              NAN              NAN             NAN
# L8.Fertility_rate           -0.105232              NAN              NAN             NAN
# L9.Life_expectancy           0.011028              NAN              NAN             NAN
# L9.Total_Population         -0.000000              NAN              NAN             NAN
# L9.Fertility_rate           -0.465092              NAN              NAN             NAN
# L10.Life_expectancy         -0.001948              NAN              NAN             NAN
# L10.Total_Population         0.000001              NAN              NAN             NAN
# L10.Fertility_rate          -0.030456              NAN              NAN             NAN
# L11.Life_expectancy          0.344681              NAN              NAN             NAN
# L11.Total_Population        -0.000000         0.000000          -10.485           0.000
# L11.Fertility_rate          -0.064013              NAN              NAN             NAN
# L12.Life_expectancy         -0.186467         0.013832          -13.481           0.000
# L12.Total_Population        -0.000000              NAN              NAN             NAN
# L12.Fertility_rate          -0.048272              NAN              NAN             NAN
# L13.Life_expectancy          0.101677         0.002109           48.209           0.000
# L13.Total_Population         0.000000              NAN              NAN             NAN
# L13.Fertility_rate           0.340080         0.054426            6.248           0.000
# L14.Life_expectancy         -0.147001         0.008772          -16.759           0.000
# L14.Total_Population        -0.000000         0.000000          -87.615           0.000
# L14.Fertility_rate           0.196417              NAN              NAN             NAN
# L15.Life_expectancy         -0.117400              NAN              NAN             NAN
# L15.Total_Population         0.000000              NAN              NAN             NAN
# L15.Fertility_rate          -0.281955              NAN              NAN             NAN
# =======================================================================================
#
# Correlation matrix of residuals
#                     Life_expectancy  Total_Population  Fertility_rate
# Life_expectancy            1.000000         -0.351656        0.201921
# Total_Population          -0.351656          1.000000       -0.418122
# Fertility_rate             0.201921         -0.418122        1.000000

# %%
# forecasting
nobs=50
pred = results.forecast(results.y, steps=nobs)
df_forecast = pd.DataFrame(pred, index=X_train.index[-nobs:], columns=X_train.columns + '_1d')
df_forecast.tail()
# inverting transformation
def invert_transformation(df_train, df_forecast, second_diff=True):
    """Revert back the differencing to get the forecast to original scale."""
    df_fc = df_forecast.copy()
    columns = df_train.columns
    for col in columns:        
        # Roll back 2nd Diff
        if second_diff:
            df_fc[str(col)+'_1d'] = (df_train[col].iloc[-1]-df_train[col].iloc[-2]) + df_fc[str(col)+'_1d'].cumsum()
        # Roll back 1st Diff
        df_fc[str(col)+'_forecast'] = df_train[col].iloc[-1] + df_fc[str(col)+'_1d'].cumsum()
    return df_fc
# show inverted results in a dataframe
df_results = invert_transformation(X_train, df_forecast, second_diff=True)        
# df_results.loc[:, ['Total_Population','Life_expectancy','Fertility_rate']]

# %%
 
Final_forecast=df_results.copy()
 
val=[i for i in range(2016,2016+len(Final_forecast))]

Final_forecast.insert(loc=0, column='Year', value=val)

Final_forecast.drop(['Life_expectancy_1d','Total_Population_1d','Fertility_rate_1d'],axis=1,inplace=True)

Final_forecast.head()
# Out:
#        Year  Life_expectancy_forecast  Total_Population_forecast  \
# 13401  2016                 65.731642               5.553937e+07
# 13402  2017                 66.516093               5.721897e+07
# 13403  2018                 67.300362               5.892020e+07
# 13404  2019                 68.078091               6.064240e+07
# 13405  2020                 68.869623               6.237889e+07
#
#        Fertility_rate_forecast
# 13401                 5.011697
# 13402                 4.943142
# 13403                 4.873463
# 13404                 4.796664
# 13405                 4.717295

# %%
print('The percentage of differnce between Actual and Forecasted result for Tanzania:')
# print("Life_expectancy  :",np.round((Final_forecast.iloc[0,1]-X_test.iloc[0,0])/X_test.iloc[0,0]*100,3),'%')
print("Total_Population :",np.round((Final_forecast.iloc[0,2]-X_test.iloc[0,1])/X_test.iloc[0,1]*100,3),'%')
# print("Fertility_rate   :",np.round((Final_forecast.iloc[0,3]-X_test.iloc[0,2])/X_test.iloc[0,2]*100,3),'%')
# Out:
# The percentage of differnce between Actual and Forecasted result for Tanzania:
# Total_Population : -0.059 %

# %%
df_final_actual=df[df['Country Name']=='Tanzania'][['Year','Total_Population']]
df_final_actual['Legend']='Actual'
df_final_forecast=pd.DataFrame(Final_forecast[['Year','Total_Population_forecast']])
df_final_forecast=df_final_forecast.rename(columns={'Total_Population_forecast':'Total_Population'})
df_final_forecast['Legend']='Forecast'
df_final=pd.concat([df_final_actual,df_final_forecast],ignore_index=True)


plt.figure(figsize=(9,7))
sns.lineplot(x='Year',y='Total_Population',data=df_final,hue='Legend',style='Legend',dashes=True)
plt.title('Forecast vs Actuals population for Tanzania')
plt.legend(loc='upper left', fontsize=18,title=None)
plt.show()

# %% [markdown]
# <b>

# %% [markdown]
# <b>

# %% [markdown]
# <b>

# %% [markdown]
# #                       ARIMA Model

# %%
data=df[df['Country Name']=='India'][['Year','Total_Population']].reset_index(drop=True)
data=data.set_index('Year')
train=data.iloc[:-1,:]
test=data.iloc[-1:,:]

# %% [markdown]
# ## Population Prediction for India

# %% [markdown]
# ### Checking Stationarity and Finding the value for hyperparameter d

# %% [markdown]
# Number of differencing required for changing non staionarity to stationary

# %%
from pmdarima.arima.utils import ndiffs

## Adf Test
print('ADF: ',ndiffs(train['Total_Population'], test='adf'))

# PP test:
print('PP',ndiffs(train['Total_Population'], test='pp'))

# KPSS test
print('KPSS',ndiffs(train['Total_Population'], test='kpss'))
# Out:
# ADF:  0
# PP 2
# KPSS 2

# %% [markdown]
# So the number of differencing need is d=2

# %% [markdown]
# ### Finding the Hyperparameter value P ( Number of lags)

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

model = pm.auto_arima(train['Total_Population'], start_p=1, start_q=1,
                      test='pp',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Fit ARIMA: order=(1, 2, 1); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 2, 0); AIC=1503.926, BIC=1507.904, Fit time=0.002 seconds
# Fit ARIMA: order=(1, 2, 0); AIC=1347.560, BIC=1353.527, Fit time=0.009 seconds
# Fit ARIMA: order=(0, 2, 1); AIC=1437.670, BIC=1443.637, Fit time=0.036 seconds
# Fit ARIMA: order=(2, 2, 0); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 2, 1); AIC=1267.596, BIC=1277.540, Fit time=0.040 seconds
# Fit ARIMA: order=(3, 2, 1); AIC=1243.254, BIC=1255.187, Fit time=0.309 seconds
# Fit ARIMA: order=(3, 2, 0); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 2, 2); AIC=1244.288, BIC=1258.211, Fit time=0.167 seconds
# Total fit time: 0.576 seconds
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                   D2.y   No. Observations:                   54
# Model:                 ARIMA(3, 2, 1)   Log Likelihood                -615.627
# Method:                       css-mle   S.D. of innovations          19995.283
# Date:                Tue, 28 Jul 2020   AIC                           1243.254
# Time:                        19:15:57   BIC                           1255.187
# Sample:                             2   HQIC                          1247.856
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.145e+05   2.31e+05      0.496      0.620   -3.38e+05    5.67e+05
# ar.L1.D2.y     2.5035      0.084     29.816      0.000       2.339       2.668
# ar.L2.D2.y    -2.3574      0.154    -15.315      0.000      -2.659      -2.056
# ar.L3.D2.y     0.8484      0.079     10.720      0.000       0.693       1.004
# ma.L1.D2.y    -0.1883      0.145     -1.298      0.194      -0.473       0.096
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0164           -0.0000j            1.0164           -0.0000
# AR.2            0.8811           -0.6191j            1.0769           -0.0975
# AR.3            0.8811           +0.6191j            1.0769            0.0975
# MA.1            5.3111           +0.0000j            5.3111            0.0000
# -----------------------------------------------------------------------------

# %%
# Build Model
# model = ARIMA(train, order=(3,2,1))  
model = ARIMA(train, order=(3, 2, 1))  
fitted = model.fit(disp=-1)  

# Forecast
fc, se, conf = fitted.forecast(15, alpha=0.05)  # 95% conf
ind=[i for i in range(2016,2031)]

# Make as pandas series
fc_series = pd.Series(fc, index=ind)
lower_series = pd.Series(conf[:, 0], index=ind)
upper_series = pd.Series(conf[:, 1], index=ind)

# Plot
plt.figure(figsize=(7,5), dpi=100)
plt.plot(train, label='training')
# plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecasted population for India with 95% confidence band')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
fitted.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARIMA Model Results
# ===============================================================================
# Dep. Variable:     D2.Total_Population   No. Observations:                   54
# Model:                  ARIMA(3, 2, 1)   Log Likelihood                -615.627
# Method:                        css-mle   S.D. of innovations          19995.283
# Date:                 Tue, 28 Jul 2020   AIC                           1243.254
# Time:                         19:16:02   BIC                           1255.187
# Sample:                              2   HQIC                          1247.856
#
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1.145e+05   2.31e+05      0.496      0.620   -3.38e+05    5.67e+05
# ar.L1.D2.Total_Population     2.5035      0.084     29.816      0.000       2.339       2.668
# ar.L2.D2.Total_Population    -2.3574      0.154    -15.315      0.000      -2.659      -2.056
# ar.L3.D2.Total_Population     0.8484      0.079     10.720      0.000       0.693       1.004
# ma.L1.D2.Total_Population    -0.1883      0.145     -1.298      0.194      -0.473       0.096
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0164           -0.0000j            1.0164           -0.0000
# AR.2            0.8811           -0.6191j            1.0769           -0.0975
# AR.3            0.8811           +0.6191j            1.0769            0.0975
# MA.1            5.3111           +0.0000j            5.3111            0.0000
# -----------------------------------------------------------------------------
# """

# %%
print('The percentage of differnce between Actual and Forecasted result for India:')
val=np.round((fc_series.iloc[0]-test.iloc[0])/test.iloc[0]*100,3)
print("Total_Population :",val.loc['Total_Population'],'%')
# Out:
# The percentage of differnce between Actual and Forecasted result for India:
# Total_Population : 0.001 %

# %%
np.round(fc_series.iloc[0])
# Out:
# 1324184558.0

# %%
print(forecast_accuracy(fc_series.iloc[0],test.iloc[0]))
# Out:
# {'mape': 0.0009971630630661544, 'rmse': 13204.14763379097}

# %% [markdown]
# ## Population Prediction for Israel

# %%
data=df[df['Country Name']=='Israel'][['Year','Total_Population']].reset_index(drop=True)
data=data.set_index('Year')
train=data.iloc[:-1,:]
test=data.iloc[-1:,:]

# %%
from pmdarima.arima.utils import ndiffs

## Adf Test
print('ADF: ',ndiffs(train['Total_Population'], test='adf'))

# PP test:
print('PP',ndiffs(train['Total_Population'], test='pp'))

# KPSS test
print('KPSS',ndiffs(train['Total_Population'], test='kpss'))
# Out:
# ADF:  2
# PP 1
# KPSS 2

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

model = pm.auto_arima(train['Total_Population'], start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Fit ARIMA: order=(1, 2, 1); AIC=1273.738, BIC=1281.694, Fit time=0.154 seconds
# Fit ARIMA: order=(0, 2, 0); AIC=1282.472, BIC=1286.450, Fit time=0.000 seconds
# Fit ARIMA: order=(1, 2, 0); AIC=1282.229, BIC=1288.196, Fit time=0.024 seconds
# Fit ARIMA: order=(0, 2, 1); AIC=1279.497, BIC=1285.464, Fit time=0.047 seconds
# Fit ARIMA: order=(2, 2, 1); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 2, 2); AIC=1275.543, BIC=1285.488, Fit time=0.213 seconds
# Fit ARIMA: order=(2, 2, 2); AIC=nan, BIC=nan, Fit time=nan seconds
# Total fit time: 0.750 seconds
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                   D2.y   No. Observations:                   54
# Model:                 ARIMA(1, 2, 1)   Log Likelihood                -632.869
# Method:                       css-mle   S.D. of innovations          28967.256
# Date:                Tue, 28 Jul 2020   AIC                           1273.738
# Time:                        18:42:33   BIC                           1281.694
# Sample:                             2   HQIC                          1276.806
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1576.8973    478.324      3.297      0.001     639.399    2514.395
# ar.L1.D2.y     0.5138      0.120      4.292      0.000       0.279       0.748
# ma.L1.D2.y    -1.0000      0.053    -18.753      0.000      -1.105      -0.895
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.9464           +0.0000j            1.9464            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------

# %%
# Build Model
# model = ARIMA(train, order=(3,2,1))  
model = ARIMA(train, order=(1, 2, 1))  
fitted = model.fit(disp=-1)  

# Forecast
fc, se, conf = fitted.forecast(15, alpha=0.05)  # 95% conf
ind=[i for i in range(2016,2031)]

# Make as pandas series
fc_series = pd.Series(fc, index=ind)
lower_series = pd.Series(conf[:, 0], index=ind)
upper_series = pd.Series(conf[:, 1], index=ind)

# Plot
plt.figure(figsize=(7,5), dpi=100)
plt.plot(train, label='training')
# plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecasted population for Israel with 95% confidence band')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
fitted.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARIMA Model Results
# ===============================================================================
# Dep. Variable:     D2.Total_Population   No. Observations:                   54
# Model:                  ARIMA(1, 2, 1)   Log Likelihood                -632.869
# Method:                        css-mle   S.D. of innovations          28967.256
# Date:                 Tue, 28 Jul 2020   AIC                           1273.738
# Time:                         18:42:41   BIC                           1281.694
# Sample:                              2   HQIC                          1276.806
#
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      1576.8973    478.324      3.297      0.001     639.399    2514.395
# ar.L1.D2.Total_Population     0.5138      0.120      4.292      0.000       0.279       0.748
# ma.L1.D2.Total_Population    -1.0000      0.053    -18.753      0.000      -1.105      -0.895
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.9464           +0.0000j            1.9464            0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# """

# %%
print('The percentage of differnce between Actual and Forecasted result for Israel:')
val=np.round((fc_series.iloc[0]-test.iloc[0])/test.iloc[0]*100,3)
print("Total_Population :",val.loc['Total_Population'],'%')
# Out:
# The percentage of differnce between Actual and Forecasted result for Israel:
# Total_Population : -0.045 %

# %%
# Accuracy metrics
def forecast_accuracy(forecast, actual):
    accuracy = 100-np.mean(np.abs(forecast - actual)/np.abs(actual))
    return round(accuracy,5)

print("Accuracy level:",forecast_accuracy(fc_series.iloc[0], test.iloc[0]))
# Out:
# Accuracy level: 99.99955

# %% [markdown]
# ## Population Prediction for Tanzania

# %%
data=df[df['Country Name']=='Tanzania'][['Year','Total_Population']].reset_index(drop=True)
data=data.set_index('Year')
train=data.iloc[:-1,:]
test=data.iloc[-1:,:]

# %%
from pmdarima.arima.utils import ndiffs

## Adf Test
print('ADF: ',ndiffs(train['Total_Population'], test='adf'))

# PP test:
print('PP',ndiffs(train['Total_Population'], test='pp'))

# KPSS test
print('KPSS',ndiffs(train['Total_Population'], test='kpss'))
# Out:
# ADF:  2
# PP 2
# KPSS 2

# %%
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

model = pm.auto_arima(train['Total_Population'], start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Fit ARIMA: order=(1, 2, 1); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(0, 2, 0); AIC=1242.462, BIC=1246.440, Fit time=0.000 seconds
# Fit ARIMA: order=(1, 2, 0); AIC=1152.620, BIC=1158.587, Fit time=0.126 seconds
# Fit ARIMA: order=(0, 2, 1); AIC=1181.642, BIC=1187.608, Fit time=0.148 seconds
# Fit ARIMA: order=(2, 2, 0); AIC=1082.238, BIC=1090.194, Fit time=0.353 seconds
# Fit ARIMA: order=(2, 2, 1); AIC=1067.993, BIC=1077.938, Fit time=0.118 seconds
# Fit ARIMA: order=(3, 2, 2); AIC=1064.663, BIC=1078.586, Fit time=0.485 seconds
# Fit ARIMA: order=(2, 2, 2); AIC=1056.694, BIC=1068.628, Fit time=0.377 seconds
# Fit ARIMA: order=(2, 2, 3); AIC=1052.687, BIC=1066.610, Fit time=0.736 seconds
# Fit ARIMA: order=(1, 2, 2); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 2, 3); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 2, 3); AIC=nan, BIC=nan, Fit time=nan seconds
# Total fit time: 3.215 seconds
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                   D2.y   No. Observations:                   54
# Model:                 ARIMA(2, 2, 3)   Log Likelihood                -519.344
# Method:                       css-mle   S.D. of innovations           3243.261
# Date:                Tue, 28 Jul 2020   AIC                           1052.687
# Time:                        18:42:55   BIC                           1066.610
# Sample:                             2   HQIC                          1058.057
#
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.504e+04   5573.054      4.493      0.000    1.41e+04     3.6e+04
# ar.L1.D2.y     1.5020      0.150      9.992      0.000       1.207       1.797
# ar.L2.D2.y    -0.6721      0.132     -5.096      0.000      -0.931      -0.414
# ma.L1.D2.y     1.1954      0.186      6.421      0.000       0.830       1.560
# ma.L2.D2.y     0.3892      0.287      1.356      0.175      -0.173       0.952
# ma.L3.D2.y    -0.3862      0.179     -2.160      0.031      -0.737      -0.036
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1173           -0.4892j            1.2197           -0.0657
# AR.2            1.1173           +0.4892j            1.2197            0.0657
# MA.1           -0.7908           -0.6121j            1.0000           -0.3952
# MA.2           -0.7908           +0.6121j            1.0000            0.3952
# MA.3            2.5893           -0.0000j            2.5893           -0.0000
# -----------------------------------------------------------------------------

# %%
# Build Model
# model = ARIMA(train, order=(3,2,1))  
model = ARIMA(train, order=(2, 2, 3))  
fitted = model.fit(disp=-1)  

# Forecast
fc, se, conf = fitted.forecast(15, alpha=0.05)  # 95% conf
ind=[i for i in range(2016,2031)]

# Make as pandas series
fc_series = pd.Series(fc, index=ind)
lower_series = pd.Series(conf[:, 0], index=ind)
upper_series = pd.Series(conf[:, 1], index=ind)

# Plot
plt.figure(figsize=(7,5), dpi=100)
plt.plot(train, label='training')
# plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecasted population for Tanzania with 95% confidence band')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
fitted.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARIMA Model Results
# ===============================================================================
# Dep. Variable:     D2.Total_Population   No. Observations:                   54
# Model:                  ARIMA(2, 2, 3)   Log Likelihood                -519.344
# Method:                        css-mle   S.D. of innovations           3243.261
# Date:                 Tue, 28 Jul 2020   AIC                           1052.687
# Time:                         18:43:03   BIC                           1066.610
# Sample:                              2   HQIC                          1058.057
#
# =============================================================================================
#                                 coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                      2.504e+04   5573.054      4.493      0.000    1.41e+04     3.6e+04
# ar.L1.D2.Total_Population     1.5020      0.150      9.992      0.000       1.207       1.797
# ar.L2.D2.Total_Population    -0.6721      0.132     -5.096      0.000      -0.931      -0.414
# ma.L1.D2.Total_Population     1.1954      0.186      6.421      0.000       0.830       1.560
# ma.L2.D2.Total_Population     0.3892      0.287      1.356      0.175      -0.173       0.952
# ma.L3.D2.Total_Population    -0.3862      0.179     -2.160      0.031      -0.737      -0.036
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.1173           -0.4892j            1.2197           -0.0657
# AR.2            1.1173           +0.4892j            1.2197            0.0657
# MA.1           -0.7908           -0.6121j            1.0000           -0.3952
# MA.2           -0.7908           +0.6121j            1.0000            0.3952
# MA.3            2.5893           -0.0000j            2.5893           -0.0000
# -----------------------------------------------------------------------------
# """

# %%
print('The percentage of differnce between Actual and Forecasted result for Tanzania:')
val=np.round((fc_series.iloc[0]-test.iloc[0])/test.iloc[0]*100,3)
print("Total_Population :",val.loc['Total_Population'],'%')
# Out:
# The percentage of differnce between Actual and Forecasted result for Tanzania:
# Total_Population : -0.004 %

# %%
# Accuracy metrics

print("Accuracy level:",forecast_accuracy(fc_series.iloc[0], test.iloc[0]))
# Out:
# Accuracy level: 99.99996

# %% [markdown]
# <br><br>
# # Exponential Smoothing

# %% [markdown]
# <b>Simple Exponential Smoothing</b>
# >When to use?<br>
#    Few data points, Irregular data, No seasonality or trend.<br><br>
#
#
# <b>Holt’s Linear Smoothing</b>
# >When to use?<br>
# Trend in data, No seasonality.<br><br>
#
#
# <b>Holt’s Damped Trend</b>
# >When to use?<br>
# Data has a trend. Use the multiplicative version, unless the data has been logged before. In this case, use the additive version

# %% [markdown]
# ## Population Prediction for India

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing, Holt


data=df[df['Country Name']=='India'][['Year','Total_Population']].reset_index(drop=True)
data=data.set_index('Year')
train=data.iloc[:-1,:]
test=data.iloc[-1:,:]

# %%
model = Holt(np.asarray(train['Total_Population']))


fit1 = model.fit(smoothing_level=.3, smoothing_slope=.05)
pred1 = fit1.forecast(15)
fit2 = model.fit(optimized=True)
pred2 = fit2.forecast(15)
fit3 = model.fit(smoothing_level=.3, smoothing_slope=.2)
pred3 = fit3.forecast(15)

# %%
fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Holt Model Results
# ================================================================================
# Dep. Variable:                  endog   No. Observations:                     56
# Model:                           Holt   SSE                 7327926054161824.000
# Optimized:                       True   AIC                             1828.287
# Trend:                       Additive   BIC                             1836.388
# Seasonal:                        None   AICC                            1830.001
# Seasonal Periods:                None   Date:                   Tue, 28 Jul 2020
# Box-Cox:                        False   Time:                           19:18:30
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.3000000                alpha                False
# smoothing_slope            0.0500000                 beta                False
# initial_level             4.4948e+08                  l.0                 True
# initial_slope             9.0144e+06                  b.0                 True
# ------------------------------------------------------------------------------
# """

# %%
fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Holt Model Results
# ===============================================================================
# Dep. Variable:                  endog   No. Observations:                    56
# Model:                           Holt   SSE                 127211151311605.250
# Optimized:                       True   AIC                            1601.285
# Trend:                       Additive   BIC                            1609.386
# Seasonal:                        None   AICC                           1602.999
# Seasonal Periods:                None   Date:                  Tue, 28 Jul 2020
# Box-Cox:                        False   Time:                          19:18:32
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.9089623                alpha                 True
# smoothing_slope            0.5780774                 beta                 True
# initial_level             4.4948e+08                  l.0                 True
# initial_slope             9.0144e+06                  b.0                 True
# ------------------------------------------------------------------------------
# """

# %%
fit3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                Holt Model Results
# ================================================================================
# Dep. Variable:                  endog   No. Observations:                     56
# Model:                           Holt   SSE                 1297217243109636.000
# Optimized:                       True   AIC                             1731.324
# Trend:                       Additive   BIC                             1739.426
# Seasonal:                        None   AICC                            1733.038
# Seasonal Periods:                None   Date:                   Tue, 28 Jul 2020
# Box-Cox:                        False   Time:                           19:18:34
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.3000000                alpha                False
# smoothing_slope            0.2000000                 beta                False
# initial_level             4.4948e+08                  l.0                 True
# initial_slope             9.0144e+06                  b.0                 True
# ------------------------------------------------------------------------------
# """

# %% [markdown]
# <b> Fit2 is better because it has lowest AIC score

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(train.index, train.values)
ind=[i for i in range(2016,2031)]
# ax.plot(test.index, test.values, color="gray")
for p, f, c in zip((pred1, pred2, pred3),(fit1, fit2, fit3),('#ff7823','#3c763d','c')):
#     ax.plot(train.index, f.fittedvalues, color=c)
    ax.plot(ind, p, label="alpha="+str(f.params['smoothing_level'])[:4]+", beta="+str(f.params['smoothing_slope'])[:4], color=c)
plt.title("Holt's Exponential Smoothing ( India )")
plt.legend();

# %%
print('The percentage of differnce between Actual and Forecasted result for India:')
f1=np.round((pred1[0]-test.iloc[0])/test.iloc[0]*100,3)
f2=np.round((pred2[0]-test.iloc[0])/test.iloc[0]*100,3)
f3=np.round((pred3[0]-test.iloc[0])/test.iloc[0]*100,3)
print("Total_Population for model with alpha= 0.3 and beta=0.05: ",f1.loc['Total_Population'],'%')
print("Total_Population for model with alpha= 0.9 and beta=0.57: ",f2.loc['Total_Population'],'%')
print("Total_Population for model with alpha= 0.3 and beta=0.2 : ",f3.loc['Total_Population'],'%')
# Out:
# The percentage of differnce between Actual and Forecasted result for India:
# Total_Population for model with alpha= 0.3 and beta=0.05:  0.274 %
# Total_Population for model with alpha= 0.9 and beta=0.57:  0.017 %
# Total_Population for model with alpha= 0.3 and beta=0.2 :  0.376 %

# %%
print(forecast_accuracy(pred2[0],test.iloc[0]))
# Out:
# {'mape': 0.01661932919357803, 'rmse': 220068.39640831947}

# %% [markdown]
# ## Population Prediction for Israel

# %%
data=df[df['Country Name']=='Israel'][['Year','Total_Population']].reset_index(drop=True)
data=data.set_index('Year')
train=data.iloc[:-1,:]
test=data.iloc[-1:,:]

# %%
model = Holt(np.asarray(train['Total_Population']))


fit1 = model.fit(smoothing_level=.3, smoothing_slope=.05)
pred1 = fit1.forecast(15)
fit2 = model.fit(optimized=True)
pred2 = fit2.forecast(15)
fit3 = model.fit(smoothing_level=.3, smoothing_slope=.2)
pred3 = fit3.forecast(15)

# %%
fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               Holt Model Results
# ==============================================================================
# Dep. Variable:                  endog   No. Observations:                   56
# Model:                           Holt   SSE                   472141164039.770
# Optimized:                       True   AIC                           1287.891
# Trend:                       Additive   BIC                           1295.992
# Seasonal:                        None   AICC                          1289.605
# Seasonal Periods:                None   Date:                 Tue, 28 Jul 2020
# Box-Cox:                        False   Time:                         19:27:25
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.3000000                alpha                False
# smoothing_slope            0.0500000                 beta                False
# initial_level             1.9808e+06                  l.0                 True
# initial_slope              99201.582                  b.0                 True
# ------------------------------------------------------------------------------
# """

# %%
fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               Holt Model Results
# ==============================================================================
# Dep. Variable:                  endog   No. Observations:                   56
# Model:                           Holt   SSE                    56336230580.292
# Optimized:                       True   AIC                           1168.838
# Trend:                       Additive   BIC                           1176.940
# Seasonal:                        None   AICC                          1170.552
# Seasonal Periods:                None   Date:                 Tue, 28 Jul 2020
# Box-Cox:                        False   Time:                         19:27:32
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            1.0000000                alpha                 True
# smoothing_slope            0.5946043                 beta                 True
# initial_level              2.053e+06                  l.0                 True
# initial_slope              50196.724                  b.0                 True
# ------------------------------------------------------------------------------
# """

# %%
fit3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               Holt Model Results
# ==============================================================================
# Dep. Variable:                  endog   No. Observations:                   56
# Model:                           Holt   SSE                   294424056769.515
# Optimized:                       True   AIC                           1261.444
# Trend:                       Additive   BIC                           1269.546
# Seasonal:                        None   AICC                          1263.159
# Seasonal Periods:                None   Date:                 Tue, 28 Jul 2020
# Box-Cox:                        False   Time:                         19:27:38
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.3000000                alpha                False
# smoothing_slope            0.2000000                 beta                False
# initial_level             2.0226e+06                  l.0                 True
# initial_slope              88218.655                  b.0                 True
# ------------------------------------------------------------------------------
# """

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(train.index, train.values)
ind=[i for i in range(2016,2031)]
# ax.plot(test.index, test.values, color="gray")
for p, f, c in zip((pred1, pred2, pred3),(fit1, fit2, fit3),('#ff7823','#3c763d','c')):
#     ax.plot(train.index, f.fittedvalues, color=c)
    ax.plot(ind, p, label="alpha="+str(f.params['smoothing_level'])[:4]+", beta="+str(f.params['smoothing_slope'])[:4], color=c)
plt.title("Holt's Exponential Smoothing ( Israel )")
plt.legend();

# %%
print('The percentage of differnce between Actual and Forecasted result for Israel:')
f1=np.round((pred1[0]-test.iloc[0])/test.iloc[0]*100,3)
f2=np.round((pred2[0]-test.iloc[0])/test.iloc[0]*100,3)
f3=np.round((pred3[0]-test.iloc[0])/test.iloc[0]*100,3)
print("Total_Population for model with alpha= 0.3 and beta=0.05: ",f1.loc['Total_Population'],'%')
print("Total_Population for model with alpha= 0.9 and beta=0.57: ",f2.loc['Total_Population'],'%')
print("Total_Population for model with alpha= 0.3 and beta=0.2 : ",f3.loc['Total_Population'],'%')
# Out:
# The percentage of differnce between Actual and Forecasted result for Israel:
# Total_Population for model with alpha= 0.3 and beta=0.05:  -1.187 %
# Total_Population for model with alpha= 0.9 and beta=0.57:  -0.074 %
# Total_Population for model with alpha= 0.3 and beta=0.2 :  -0.68 %

# %%
print(forecast_accuracy(pred2[0],test.iloc[0]))
# Out:
# {'mape': 0.07400637242442623, 'rmse': 6324.584587391466}

# %% [markdown]
# ## Population Prediction for Tanzania

# %%
data=df[df['Country Name']=='Tanzania'][['Year','Total_Population']].reset_index(drop=True)
data=data.set_index('Year')
train=data.iloc[:-1,:]
test=data.iloc[-1:,:]

# %%
model = Holt(np.asarray(train['Total_Population']))


fit1 = model.fit(smoothing_level=.3, smoothing_slope=.05)
pred1 = fit1.forecast(15)
fit2 = model.fit(optimized=True)
pred2 = fit2.forecast(15)
fit3 = model.fit(smoothing_level=.3, smoothing_slope=.2)
pred3 = fit3.forecast(15)

# %%
fit1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               Holt Model Results
# ==============================================================================
# Dep. Variable:                  endog   No. Observations:                   56
# Model:                           Holt   SSE                 51486736632805.031
# Optimized:                       True   AIC                           1550.632
# Trend:                       Additive   BIC                           1558.733
# Seasonal:                        None   AICC                          1552.346
# Seasonal Periods:                None   Date:                 Tue, 28 Jul 2020
# Box-Cox:                        False   Time:                         19:33:01
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.3000000                alpha                False
# smoothing_slope            0.0500000                 beta                False
# initial_level              1.001e+07                  l.0                 True
# initial_slope             6.7645e+05                  b.0                 True
# ------------------------------------------------------------------------------
# """

# %%
fit2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               Holt Model Results
# ==============================================================================
# Dep. Variable:                  endog   No. Observations:                   56
# Model:                           Holt   SSE                   234725011435.111
# Optimized:                       True   AIC                           1248.754
# Trend:                       Additive   BIC                           1256.856
# Seasonal:                        None   AICC                          1250.469
# Seasonal Periods:                None   Date:                 Tue, 28 Jul 2020
# Box-Cox:                        False   Time:                         19:33:07
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.9473684                alpha                 True
# smoothing_slope            0.9473684                 beta                 True
# initial_level             1.0075e+07                  l.0                 True
# initial_slope             2.9889e+05                  b.0                 True
# ------------------------------------------------------------------------------
# """

# %%
fit3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               Holt Model Results
# ==============================================================================
# Dep. Variable:                  endog   No. Observations:                   56
# Model:                           Holt   SSE                 10380414976923.260
# Optimized:                       True   AIC                           1460.953
# Trend:                       Additive   BIC                           1469.054
# Seasonal:                        None   AICC                          1462.667
# Seasonal Periods:                None   Date:                 Tue, 28 Jul 2020
# Box-Cox:                        False   Time:                         19:33:14
# Box-Cox Coeff.:                  None
# ==============================================================================
#                        coeff                 code              optimized
# ------------------------------------------------------------------------------
# smoothing_level            0.3000000                alpha                False
# smoothing_slope            0.2000000                 beta                False
# initial_level             9.6367e+06                  l.0                 True
# initial_slope             3.3988e+05                  b.0                 True
# ------------------------------------------------------------------------------
# """

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.plot(train.index, train.values)
ind=[i for i in range(2016,2031)]
# ax.plot(test.index, test.values, color="gray")
for p, f, c in zip((pred1, pred2, pred3),(fit1, fit2, fit3),('#ff7823','#3c763d','c')):
#     ax.plot(train.index, f.fittedvalues, color=c)
    ax.plot(ind, p, label="alpha="+str(f.params['smoothing_level'])[:4]+", beta="+str(f.params['smoothing_slope'])[:4], color=c)
plt.title("Holt's Exponential Smoothing ( Tanzania )")
plt.legend();

# %%
print('The percentage of differnce between Actual and Forecasted result for Tanzania:')
f1=np.round((pred1[0]-test.iloc[0])/test.iloc[0]*100,3)
f2=np.round((pred2[0]-test.iloc[0])/test.iloc[0]*100,3)
f3=np.round((pred3[0]-test.iloc[0])/test.iloc[0]*100,3)
print("Total_Population for model with alpha= 0.3 and beta=0.05: ",f1.loc['Total_Population'],'%')
print("Total_Population for model with alpha= 0.9 and beta=0.57: ",f2.loc['Total_Population'],'%')
print("Total_Population for model with alpha= 0.3 and beta=0.2 : ",f3.loc['Total_Population'],'%')
# Out:
# The percentage of differnce between Actual and Forecasted result for Tanzania:
# Total_Population for model with alpha= 0.3 and beta=0.05:  -3.822 %
# Total_Population for model with alpha= 0.9 and beta=0.57:  -0.095 %
# Total_Population for model with alpha= 0.3 and beta=0.2 :  -1.473 %

# %%
print(forecast_accuracy(pred2[0],test.iloc[0]))
# Out:
# {'mape': 0.09470035049415923, 'rmse': 52627.06912431866}
